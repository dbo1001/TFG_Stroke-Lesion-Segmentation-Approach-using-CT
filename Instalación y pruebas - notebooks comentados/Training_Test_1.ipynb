# %%
# %cd /home/bsc0001/niftynet
# Out:
# /home/bsc0001/niftynet

# %%
# !pip install SimpleITK
# !pip install pyyaml
# Out:
# Requirement already satisfied: SimpleITK in ./lib/python3.6/site-packages (1.2.0)
# Collecting pyyaml
#   Downloading https://files.pythonhosted.org/packages/a3/65/837fefac7475963d1eccf4aa684c23b95aa6c1d033a2c5965ccb11e22623/PyYAML-5.1.1.tar.gz (274kB)
#      |████████████████████████████████| 276kB 700kB/s eta 0:00:01
# Building wheels for collected packages: pyyaml
#   Building wheel for pyyaml (setup.py) ... done
#   Stored in directory: /home/bsc0001/.cache/pip/wheels/16/27/a1/775c62ddea7bfa62324fd1f65847ed31c55dadb6051481ba3f
# Successfully built pyyaml
# Installing collected packages: pyyaml
# Successfully installed pyyaml-5.1.1

# %%
! net_segment train -c /home/bsc0001/niftynet/extensions/dense_vnet_TC_craneal/config.ini --name dense_vnet_TC_craneal.CNN_TC_craneal_ictus.MyNet
# Out:
# CRITICAL:tensorflow:Optional Python module cv2 not found, please install cv2 and retry if the application fails.
# CRITICAL:tensorflow:Optional Python module skimage.io not found, please install skimage.io and retry if the application fails.
# NiftyNet version 0.5.0
# [CUSTOM]
# -- num_classes: 2
# -- output_prob: False
# -- label_normalisation: False
# -- softmax: True
# -- min_sampling_ratio: 0
# -- compulsory_labels: (0, 1)
# -- rand_samples: 0
# -- min_numb_labels: 1
# -- proba_connect: True
# -- evaluation_units: foreground
# -- image: ('ct',)
# -- weight: ()
# -- label: ('label',)
# -- sampler: ()
# -- inferred: ()
# -- name: net_segment
# [CONFIG_FILE]
# -- path: /home/bsc0001/niftynet/extensions/dense_vnet_TC_craneal/config.ini
# [CT]
# -- csv_file:
# -- path_to_search: ./data/dense_vnet_TC_craneal/
# -- filename_contains: ('TC',)
# -- filename_not_contains: ()
# -- filename_removefromid:
# -- interp_order: 1
# -- loader: None
# -- pixdim: ()
# -- axcodes: ('A', 'R', 'S')
# -- spatial_window_size: (512, 512, 40)
# [LABEL]
# -- csv_file:
# -- path_to_search: ./data/dense_vnet_TC_craneal/
# -- filename_contains: ('mask',)
# -- filename_not_contains: ()
# -- filename_removefromid:
# -- interp_order: 0
# -- loader: None
# -- pixdim: ()
# -- axcodes: ('A', 'R', 'S')
# -- spatial_window_size: (512, 512, 40)
# [SYSTEM]
# -- cuda_devices: ""
# -- num_threads: 1
# -- num_gpus: 1
# -- model_dir: /home/bsc0001/niftynet/models/dense_vnet_TC_craneal
# -- dataset_split_file: ./dataset_split.csv
# -- event_handler: ('model_saver', 'model_restorer', 'sampler_threading', 'apply_gradients', 'output_interpreter', 'console_logger', 'tensorboard_logger')
# -- iteration_generator: iteration_generator
# -- action: training
# [NETWORK]
# -- name: dense_vnet_TC_craneal.CNN_TC_craneal_ictus.MyNet
# -- activation_function: relu
# -- batch_size: 6
# -- smaller_final_batch_mode: pad
# -- decay: 0.0
# -- reg_type: L2
# -- volume_padding_size: (0, 0, 0)
# -- volume_padding_mode: minimum
# -- window_sampling: resize
# -- queue_length: 36
# -- multimod_foreground_type: and
# -- histogram_ref_file: ./histogram_ref_file.txt
# -- norm_type: percentile
# -- cutoff: (0.01, 0.99)
# -- foreground_type: otsu_plus
# -- normalisation: False
# -- whitening: False
# -- normalise_foreground_only: False
# -- weight_initializer: he_normal
# -- bias_initializer: zeros
# -- keep_prob: 1.0
# -- weight_initializer_args: {}
# -- bias_initializer_args: {}
# [TRAINING]
# -- optimiser: adam
# -- sample_per_volume: 1
# -- rotation_angle: ()
# -- rotation_angle_x: ()
# -- rotation_angle_y: ()
# -- rotation_angle_z: ()
# -- scaling_percentage: ()
# -- antialiasing: True
# -- bias_field_range: ()
# -- bf_order: 3
# -- random_flipping_axes: -1
# -- do_elastic_deformation: False
# -- num_ctrl_points: 4
# -- deformation_sigma: 15
# -- proportion_to_deform: 0.5
# -- lr: 0.001
# -- loss_type: dense_vnet_TC_craneal.dice_hinge.dice
# -- starting_iter: 0
# -- save_every_n: 1000
# -- tensorboard_every_n: 20
# -- max_iter: 3001
# -- max_checkpoints: 100
# -- validation_every_n: -1
# -- validation_max_iter: 1
# -- exclude_fraction_for_validation: 0.0
# -- exclude_fraction_for_inference: 0.0
# -- vars_to_restore:
# -- vars_to_freeze:
# [INFERENCE]
# -- spatial_window_size: (512, 512, 40)
# -- inference_iter: 3000
# -- dataset_to_infer:
# -- save_seg_dir: ./segmentation_output/
# -- output_postfix: _niftynet_out
# -- output_interp_order: 0
# -- border: (0, 0, 0)
# INFO:niftynet: starting segmentation application
# INFO:niftynet: `csv_file = ` not found, writing to "/home/bsc0001/niftynet/models/dense_vnet_TC_craneal/ct.csv" instead.
# INFO:niftynet: Overwriting existing: "/home/bsc0001/niftynet/models/dense_vnet_TC_craneal/ct.csv".
# INFO:niftynet: [ct] search file folders, writing csv file /home/bsc0001/niftynet/models/dense_vnet_TC_craneal/ct.csv
# INFO:niftynet: `csv_file = ` not found, writing to "/home/bsc0001/niftynet/models/dense_vnet_TC_craneal/label.csv" instead.
# INFO:niftynet: Overwriting existing: "/home/bsc0001/niftynet/models/dense_vnet_TC_craneal/label.csv".
# INFO:niftynet: [label] search file folders, writing csv file /home/bsc0001/niftynet/models/dense_vnet_TC_craneal/label.csv
# INFO:niftynet:
#
# Number of subjects 2, input section names: ['subject_id', 'ct', 'label']
# -- using all subjects (without data partitioning).
#
# INFO:niftynet: Image reader: loading 2 subjects from sections ('ct',) as input [image]
# INFO:niftynet: Image reader: loading 2 subjects from sections ('label',) as input [label]
#
# system_param:  {'SYSTEM': Namespace(action='training', cuda_devices='""', dataset_split_file='/home/bsc0001/niftynet/models/dense_vnet_TC_craneal/dataset_split.csv', event_handler=('model_saver', 'model_restorer', 'sampler_threading', 'apply_gradients', 'output_interpreter', 'console_logger', 'tensorboard_logger'), iteration_generator='iteration_generator', model_dir='/home/bsc0001/niftynet/models/dense_vnet_TC_craneal', num_gpus=1, num_threads=1), 'NETWORK': Namespace(activation_function='relu', batch_size=6, bias_initializer='zeros', bias_initializer_args={}, cutoff=(0.01, 0.99), decay=0.0, foreground_type='otsu_plus', histogram_ref_file='/home/bsc0001/niftynet/models/dense_vnet_TC_craneal/histogram_ref_file.txt', keep_prob=1.0, multimod_foreground_type='and', name='dense_vnet_TC_craneal.CNN_TC_craneal_ictus.MyNet', norm_type='percentile', normalisation=False, normalise_foreground_only=False, queue_length=36, reg_type='L2', smaller_final_batch_mode='pad', volume_padding_mode='minimum', volume_padding_size=(0, 0, 0), weight_initializer='he_normal', weight_initializer_args={}, whitening=False, window_sampling='resize'), 'TRAINING': Namespace(antialiasing=True, bf_order=3, bias_field_range=(), deformation_sigma=15, do_elastic_deformation=False, exclude_fraction_for_inference=0.0, exclude_fraction_for_validation=0.0, loss_type='dense_vnet_TC_craneal.dice_hinge.dice', lr=0.001, max_checkpoints=100, max_iter=3001, num_ctrl_points=4, optimiser='adam', proportion_to_deform=0.5, random_flipping_axes=-1, rotation_angle=(), rotation_angle_x=(), rotation_angle_y=(), rotation_angle_z=(), sample_per_volume=1, save_every_n=1000, scaling_percentage=(), starting_iter=0, tensorboard_every_n=20, validation_every_n=-1, validation_max_iter=1, vars_to_freeze='', vars_to_restore=''), 'INFERENCE': Namespace(border=(0, 0, 0), dataset_to_infer='', inference_iter=3000, output_interp_order=0, output_postfix='_niftynet_out', save_seg_dir='/home/bsc0001/niftynet/models/dense_vnet_TC_craneal/segmentation_output', spatial_window_size=(512, 512, 40)), 'CUSTOM': Namespace(compulsory_labels=(0, 1), evaluation_units='foreground', image=('ct',), inferred=(), label=('label',), label_normalisation=False, min_numb_labels=1, min_sampling_ratio=0, name='net_segment', num_classes=2, output_prob=False, proba_connect=True, rand_samples=0, sampler=(), softmax=True, weight=()), 'CONFIG_FILE': Namespace(path='/home/bsc0001/niftynet/extensions/dense_vnet_TC_craneal/config.ini')}
#
# input_data_param: {'ct': Namespace(axcodes=('A', 'R', 'S'), csv_file='', filename_contains=('TC',), filename_not_contains=(), filename_removefromid='', interp_order=1, loader=None, path_to_search='./data/dense_vnet_TC_craneal/', pixdim=(), spatial_window_size=(512, 512, 40)), 'label': Namespace(axcodes=('A', 'R', 'S'), csv_file='', filename_contains=('mask',), filename_not_contains=(), filename_removefromid='', interp_order=0, loader=None, path_to_search='./data/dense_vnet_TC_craneal/', pixdim=(), spatial_window_size=(512, 512, 40))}
#
#
# Params al crear graph:
# App:  <niftynet.application.segmentation_application.SegmentationApplication object at 0x7f3e5a104668>
# Num_GPUs:  1
# Num_hilos:  1
# Is training?:  True
#
# 2019-06-17 18:51:33.778461: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-06-17 18:51:33.939259: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1411] Found device 0 with properties:
# name: TITAN Xp major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:05:00.0
# totalMemory: 11.91GiB freeMemory: 11.14GiB
# 2019-06-17 18:51:34.056403: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1411] Found device 1 with properties:
# name: TITAN Xp major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:06:00.0
# totalMemory: 11.91GiB freeMemory: 11.20GiB
# 2019-06-17 18:51:34.173786: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1411] Found device 2 with properties:
# name: TITAN Xp major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:09:00.0
# totalMemory: 11.91GiB freeMemory: 11.20GiB
# 2019-06-17 18:51:34.174175: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1490] Adding visible gpu devices: 0, 1, 2
# 2019-06-17 18:51:34.943922: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-06-17 18:51:34.943958: I tensorflow/core/common_runtime/gpu/gpu_device.cc:977]      0 1 2
# 2019-06-17 18:51:34.943964: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 0:   N Y Y
# 2019-06-17 18:51:34.943969: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 1:   Y N Y
# 2019-06-17 18:51:34.943973: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 2:   Y Y N
# 2019-06-17 18:51:34.944666: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/device:GPU:0 with 10771 MB memory) -> physical GPU (device: 0, name: TITAN Xp, pci bus id: 0000:05:00.0, compute capability: 6.1)
# 2019-06-17 18:51:35.090955: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/device:GPU:1 with 10835 MB memory) -> physical GPU (device: 1, name: TITAN Xp, pci bus id: 0000:06:00.0, compute capability: 6.1)
# 2019-06-17 18:51:35.237716: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/device:GPU:2 with 10835 MB memory) -> physical GPU (device: 2, name: TITAN Xp, pci bus id: 0000:09:00.0, compute capability: 6.1)
# INFO:niftynet: reading size of preprocessed images
# INFO:niftynet: initialised resize sampler {'image': (1, 512, 512, 40, 1, 1), 'image_location': (1, 7), 'label': (1, 512, 512, 40, 1, 1), 'label_location': (1, 7)}
# WARNING:niftynet: From /home/bsc0001/niftynet/lib/python3.6/site-packages/niftynet/engine/application_initializer.py:106: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with distribution=normal is deprecated and will be removed in a future version.
# Instructions for updating:
# `normal` is a deprecated alias for `truncated_normal`
#
# Should be:
#  <tensorflow.python.ops.init_ops.VarianceScaling object at 0x7f3e5a0eab70>
#
#
# W_INIT:
#  <tensorflow.python.ops.init_ops.VarianceScaling object at 0x7f3e5a104e80>
#
# INFO:niftynet: Import [MyNet] from /home/bsc0001/niftynet/extensions/dense_vnet_TC_craneal/CNN_TC_craneal_ictus.py.
#
# Should be:
#  <tensorflow.python.ops.init_ops.VarianceScaling object at 0x7f3e5a104e80>
#
# INFO:niftynet: using MyNet
# 2019-06-17 18:51:35.526650: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1490] Adding visible gpu devices: 0, 1, 2
# 2019-06-17 18:51:35.526891: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-06-17 18:51:35.526915: I tensorflow/core/common_runtime/gpu/gpu_device.cc:977]      0 1 2
# 2019-06-17 18:51:35.526930: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 0:   N Y Y
# 2019-06-17 18:51:35.526943: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 1:   Y N Y
# 2019-06-17 18:51:35.526955: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 2:   Y Y N
# 2019-06-17 18:51:35.527524: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/device:GPU:0 with 10771 MB memory) -> physical GPU (device: 0, name: TITAN Xp, pci bus id: 0000:05:00.0, compute capability: 6.1)
# 2019-06-17 18:51:35.527937: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/device:GPU:1 with 10835 MB memory) -> physical GPU (device: 1, name: TITAN Xp, pci bus id: 0000:06:00.0, compute capability: 6.1)
# 2019-06-17 18:51:35.528179: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/device:GPU:2 with 10835 MB memory) -> physical GPU (device: 2, name: TITAN Xp, pci bus id: 0000:09:00.0, compute capability: 6.1)
# INFO:niftynet: Initialising Dataset from 2 subjects...
# INFO:niftynet: Import [dice] from /home/bsc0001/niftynet/extensions/dense_vnet_TC_craneal/dice_hinge.py.
# 2019-06-17 18:51:36.745815: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1490] Adding visible gpu devices: 0, 1, 2
# 2019-06-17 18:51:36.745959: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-06-17 18:51:36.745970: I tensorflow/core/common_runtime/gpu/gpu_device.cc:977]      0 1 2
# 2019-06-17 18:51:36.745977: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 0:   N Y Y
# 2019-06-17 18:51:36.745983: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 1:   Y N Y
# 2019-06-17 18:51:36.745989: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 2:   Y Y N
# 2019-06-17 18:51:36.746294: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10771 MB memory) -> physical GPU (device: 0, name: TITAN Xp, pci bus id: 0000:05:00.0, compute capability: 6.1)
# 2019-06-17 18:51:36.746492: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 10835 MB memory) -> physical GPU (device: 1, name: TITAN Xp, pci bus id: 0000:06:00.0, compute capability: 6.1)
# 2019-06-17 18:51:36.746690: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:2 with 10835 MB memory) -> physical GPU (device: 2, name: TITAN Xp, pci bus id: 0000:09:00.0, compute capability: 6.1)
# INFO:niftynet: Parameters from random initialisations ...
# 2019-06-17 18:51:50.948363: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:98] Filling up shuffle buffer (this may take a while): 32 of 36
# 2019-06-17 18:51:52.185442: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:136] Shuffle buffer filled.
# dice[-nan -nan]
# dice[-nan -nan]
# dice[-nan -nan]
# dice[-nan -nan]
# dice[-nan -nan]
# dice[-nan -nan]
# 2019-06-17 18:52:26.866185: W tensorflow/core/common_runtime/bfc_allocator.cc:271] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.34GiB.  Current allocation summary follows.
# 2019-06-17 18:52:26.866251: I tensorflow/core/common_runtime/bfc_allocator.cc:610] Bin (256): 	Total Chunks: 78, Chunks in use: 77. 19.5KiB allocated for chunks. 19.2KiB in use in bin. 1.4KiB client-requested in use in bin.
# 2019-06-17 18:52:26.866270: I tensorflow/core/common_runtime/bfc_allocator.cc:610] Bin (512): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2019-06-17 18:52:26.866289: I tensorflow/core/common_runtime/bfc_allocator.cc:610] Bin (1024): 	Total Chunks: 5, Chunks in use: 5. 6.2KiB allocated for chunks. 6.2KiB in use in bin. 5.2KiB client-requested in use in bin.
# 2019-06-17 18:52:26.866305: I tensorflow/core/common_runtime/bfc_allocator.cc:610] Bin (2048): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2019-06-17 18:52:26.866321: I tensorflow/core/common_runtime/bfc_allocator.cc:610] Bin (4096): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2019-06-17 18:52:26.866336: I tensorflow/core/common_runtime/bfc_allocator.cc:610] Bin (8192): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2019-06-17 18:52:26.866351: I tensorflow/core/common_runtime/bfc_allocator.cc:610] Bin (16384): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2019-06-17 18:52:26.866366: I tensorflow/core/common_runtime/bfc_allocator.cc:610] Bin (32768): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2019-06-17 18:52:26.866380: I tensorflow/core/common_runtime/bfc_allocator.cc:610] Bin (65536): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2019-06-17 18:52:26.866395: I tensorflow/core/common_runtime/bfc_allocator.cc:610] Bin (131072): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2019-06-17 18:52:26.866410: I tensorflow/core/common_runtime/bfc_allocator.cc:610] Bin (262144): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2019-06-17 18:52:26.866425: I tensorflow/core/common_runtime/bfc_allocator.cc:610] Bin (524288): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2019-06-17 18:52:26.866440: I tensorflow/core/common_runtime/bfc_allocator.cc:610] Bin (1048576): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2019-06-17 18:52:26.866455: I tensorflow/core/common_runtime/bfc_allocator.cc:610] Bin (2097152): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2019-06-17 18:52:26.866470: I tensorflow/core/common_runtime/bfc_allocator.cc:610] Bin (4194304): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2019-06-17 18:52:26.866485: I tensorflow/core/common_runtime/bfc_allocator.cc:610] Bin (8388608): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2019-06-17 18:52:26.866500: I tensorflow/core/common_runtime/bfc_allocator.cc:610] Bin (16777216): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2019-06-17 18:52:26.866515: I tensorflow/core/common_runtime/bfc_allocator.cc:610] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2019-06-17 18:52:26.866530: I tensorflow/core/common_runtime/bfc_allocator.cc:610] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2019-06-17 18:52:26.866545: I tensorflow/core/common_runtime/bfc_allocator.cc:610] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2019-06-17 18:52:26.866562: I tensorflow/core/common_runtime/bfc_allocator.cc:610] Bin (268435456): 	Total Chunks: 8, Chunks in use: 4. 10.52GiB allocated for chunks. 7.50GiB in use in bin. 7.50GiB client-requested in use in bin.
# 2019-06-17 18:52:26.866580: I tensorflow/core/common_runtime/bfc_allocator.cc:626] Bin for 2.34GiB was 256.00MiB, Chunk State:
# 2019-06-17 18:52:26.866605: I tensorflow/core/common_runtime/bfc_allocator.cc:632]   Size: 480.00MiB | Requested Size: 80.00MiB | in_use: 0, prev:   Size: 256B | Requested Size: 4B | in_use: 1, next:   Size: 480.00MiB | Requested Size: 480.00MiB | in_use: 1
# 2019-06-17 18:52:26.866627: I tensorflow/core/common_runtime/bfc_allocator.cc:632]   Size: 480.00MiB | Requested Size: 480.00MiB | in_use: 0, prev:   Size: 2.34GiB | Requested Size: 2.34GiB | in_use: 1, next:   Size: 256B | Requested Size: 4B | in_use: 1
# 2019-06-17 18:52:26.866647: I tensorflow/core/common_runtime/bfc_allocator.cc:632]   Size: 720.00MiB | Requested Size: 480.00MiB | in_use: 0, prev:   Size: 256B | Requested Size: 40B | in_use: 1, next:   Size: 2.34GiB | Requested Size: 2.34GiB | in_use: 1
# 2019-06-17 18:52:26.866665: I tensorflow/core/common_runtime/bfc_allocator.cc:632]   Size: 1.38GiB | Requested Size: 480.00MiB | in_use: 0, prev:   Size: 480.00MiB | Requested Size: 480.00MiB | in_use: 1
# 2019-06-17 18:52:26.866681: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae000000 of size 1280
# 2019-06-17 18:52:26.866694: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae000500 of size 256
# 2019-06-17 18:52:26.866707: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae000600 of size 256
# 2019-06-17 18:52:26.866719: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae000700 of size 256
# 2019-06-17 18:52:26.866731: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae000800 of size 256
# 2019-06-17 18:52:26.866743: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae000900 of size 256
# 2019-06-17 18:52:26.866755: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae000a00 of size 256
# 2019-06-17 18:52:26.866767: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae000b00 of size 256
# 2019-06-17 18:52:26.866779: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae000c00 of size 256
# 2019-06-17 18:52:26.866791: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae000d00 of size 256
# 2019-06-17 18:52:26.866803: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae000e00 of size 256
# 2019-06-17 18:52:26.866815: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae000f00 of size 256
# 2019-06-17 18:52:26.866827: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae001000 of size 1280
# 2019-06-17 18:52:26.866839: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae001500 of size 256
# 2019-06-17 18:52:26.866851: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae001600 of size 256
# 2019-06-17 18:52:26.866863: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae001700 of size 256
# 2019-06-17 18:52:26.866875: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae001800 of size 256
# 2019-06-17 18:52:26.866887: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae001900 of size 256
# 2019-06-17 18:52:26.866899: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae001a00 of size 256
# 2019-06-17 18:52:26.866911: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae001b00 of size 256
# 2019-06-17 18:52:26.866923: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae001c00 of size 256
# 2019-06-17 18:52:26.866936: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae001d00 of size 256
# 2019-06-17 18:52:26.866948: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae001e00 of size 256
# 2019-06-17 18:52:26.866960: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae001f00 of size 256
# 2019-06-17 18:52:26.866972: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae002000 of size 256
# 2019-06-17 18:52:26.866984: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae002100 of size 256
# 2019-06-17 18:52:26.866996: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae002200 of size 256
# 2019-06-17 18:52:26.867008: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae002300 of size 256
# 2019-06-17 18:52:26.867020: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae002400 of size 256
# 2019-06-17 18:52:26.867032: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae002500 of size 256
# 2019-06-17 18:52:26.867044: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae002600 of size 256
# 2019-06-17 18:52:26.867056: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae002700 of size 256
# 2019-06-17 18:52:26.867068: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae002800 of size 256
# 2019-06-17 18:52:26.867080: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae002900 of size 256
# 2019-06-17 18:52:26.867093: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae002a00 of size 256
# 2019-06-17 18:52:26.867105: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae002b00 of size 256
# 2019-06-17 18:52:26.867117: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae002c00 of size 256
# 2019-06-17 18:52:26.867129: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae002d00 of size 256
# 2019-06-17 18:52:26.867141: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae002e00 of size 256
# 2019-06-17 18:52:26.867153: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae002f00 of size 256
# 2019-06-17 18:52:26.867165: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae003000 of size 256
# 2019-06-17 18:52:26.867177: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae003100 of size 256
# 2019-06-17 18:52:26.867189: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae003200 of size 256
# 2019-06-17 18:52:26.867201: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae003300 of size 256
# 2019-06-17 18:52:26.867213: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae003400 of size 256
# 2019-06-17 18:52:26.867225: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae003500 of size 256
# 2019-06-17 18:52:26.867237: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae003600 of size 1280
# 2019-06-17 18:52:26.867249: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae003b00 of size 1280
# 2019-06-17 18:52:26.867261: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae004000 of size 1280
# 2019-06-17 18:52:26.867273: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae004500 of size 256
# 2019-06-17 18:52:26.867285: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae004600 of size 256
# 2019-06-17 18:52:26.867297: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae004700 of size 256
# 2019-06-17 18:52:26.867309: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae004800 of size 256
# 2019-06-17 18:52:26.867321: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae004900 of size 256
# 2019-06-17 18:52:26.867333: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae004a00 of size 256
# 2019-06-17 18:52:26.867345: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae004b00 of size 256
# 2019-06-17 18:52:26.867357: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae004c00 of size 256
# 2019-06-17 18:52:26.867369: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae004d00 of size 256
# 2019-06-17 18:52:26.867381: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae004e00 of size 256
# 2019-06-17 18:52:26.867393: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae004f00 of size 256
# 2019-06-17 18:52:26.867405: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae005000 of size 256
# 2019-06-17 18:52:26.867417: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae005100 of size 256
# 2019-06-17 18:52:26.867429: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae005200 of size 256
# 2019-06-17 18:52:26.867441: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae005300 of size 256
# 2019-06-17 18:52:26.867453: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae005400 of size 256
# 2019-06-17 18:52:26.867465: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae005500 of size 256
# 2019-06-17 18:52:26.867477: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae005600 of size 256
# 2019-06-17 18:52:26.867489: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae005700 of size 256
# 2019-06-17 18:52:26.867501: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae005800 of size 256
# 2019-06-17 18:52:26.867513: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae005900 of size 256
# 2019-06-17 18:52:26.867525: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae005a00 of size 256
# 2019-06-17 18:52:26.867538: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae005b00 of size 256
# 2019-06-17 18:52:26.867549: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae005c00 of size 256
# 2019-06-17 18:52:26.867562: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae005d00 of size 256
# 2019-06-17 18:52:26.867574: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae005e00 of size 256
# 2019-06-17 18:52:26.867586: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Free  at 0x7f3aae005f00 of size 256
# 2019-06-17 18:52:26.867598: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae006000 of size 256
# 2019-06-17 18:52:26.867610: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae006100 of size 256
# 2019-06-17 18:52:26.867622: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3aae006200 of size 256
# 2019-06-17 18:52:26.867634: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Free  at 0x7f3aae006300 of size 754973952
# 2019-06-17 18:52:26.867646: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3adb006000 of size 2516582400
# 2019-06-17 18:52:26.867659: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3b71006000 of size 2516582400
# 2019-06-17 18:52:26.867671: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3c07006000 of size 2516582400
# 2019-06-17 18:52:26.867683: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Free  at 0x7f3c9d006000 of size 503316480
# 2019-06-17 18:52:26.867695: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3cbb006000 of size 256
# 2019-06-17 18:52:26.867707: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3cbb006100 of size 256
# 2019-06-17 18:52:26.867719: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3cbb006200 of size 256
# 2019-06-17 18:52:26.867731: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3cbb006300 of size 256
# 2019-06-17 18:52:26.867743: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Free  at 0x7f3cbb006400 of size 503315712
# 2019-06-17 18:52:26.867756: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Chunk at 0x7f3cd9006100 of size 503316480
# 2019-06-17 18:52:26.867768: I tensorflow/core/common_runtime/bfc_allocator.cc:645] Free  at 0x7f3cf7006100 of size 1479682816
# 2019-06-17 18:52:26.867780: I tensorflow/core/common_runtime/bfc_allocator.cc:651]      Summary of in-use Chunks by size:
# 2019-06-17 18:52:26.867795: I tensorflow/core/common_runtime/bfc_allocator.cc:654] 77 Chunks of size 256 totalling 19.2KiB
# 2019-06-17 18:52:26.867809: I tensorflow/core/common_runtime/bfc_allocator.cc:654] 5 Chunks of size 1280 totalling 6.2KiB
# 2019-06-17 18:52:26.867823: I tensorflow/core/common_runtime/bfc_allocator.cc:654] 1 Chunks of size 503316480 totalling 480.00MiB
# 2019-06-17 18:52:26.867837: I tensorflow/core/common_runtime/bfc_allocator.cc:654] 3 Chunks of size 2516582400 totalling 7.03GiB
# 2019-06-17 18:52:26.867850: I tensorflow/core/common_runtime/bfc_allocator.cc:658] Sum Total of in-use chunks: 7.50GiB
# 2019-06-17 18:52:26.867869: I tensorflow/core/common_runtime/bfc_allocator.cc:660] Stats:
# Limit:                 11294379213
# InUse:                  8053089792
# MaxInUse:               9898582016
# NumAllocs:                     156
# MaxAllocSize:           2516582400
#
# 2019-06-17 18:52:26.867902: W tensorflow/core/common_runtime/bfc_allocator.cc:275] *_____********************************************************************___*____*****_____________
# 2019-06-17 18:52:26.867951: W tensorflow/core/framework/op_kernel.cc:1273] OP_REQUIRES failed at conv_grad_ops_3d.cc:537 : Resource exhausted: OOM when allocating tensor with shape[6,512,512,40,10] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# INFO:niftynet: cleaning up...
# INFO:niftynet: stopping sampling threads
# INFO:niftynet: iter 1 saved: /home/bsc0001/niftynet/models/dense_vnet_TC_craneal/models/model.ckpt
# Traceback (most recent call last):
#   File "/home/bsc0001/niftynet/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1292, in _do_call
#     return fn(*args)
#   File "/home/bsc0001/niftynet/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1277, in _run_fn
#     options, feed_dict, fetch_list, target_list, run_metadata)
#   File "/home/bsc0001/niftynet/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1367, in _call_tf_sessionrun
#     run_metadata)
# tensorflow.python.framework.errors_impl.ResourceExhaustedError: OOM when allocating tensor with shape[6,512,512,40,10] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node worker_0/gradients/worker_0/MyNet/conv_output_bn/conv_/conv_grad/Conv3DBackpropInputV2}} = Conv3DBackpropInputV2[T=DT_FLOAT, Tshape=DT_INT32, data_format="NDHWC", dilations=[1, 1, 1, 1, 1], padding="SAME", strides=[1, 1, 1, 1, 1], _device="/job:localhost/replica:0/task:0/device:GPU:0"](worker_0/gradients/worker_0/MyNet/conv_output_bn/conv_/conv_grad/Shape, MyNet/conv_output_bn/conv_/w/read, worker_0/gradients/AddN_3)]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/bsc0001/niftynet/bin/net_segment", line 10, in <module>
#     sys.exit(main())
#   File "/home/bsc0001/niftynet/lib/python3.6/site-packages/niftynet/__init__.py", line 146, in main
#     app_driver.run(app_driver.app)
#   File "/home/bsc0001/niftynet/lib/python3.6/site-packages/niftynet/engine/application_driver.py", line 212, in run
#     loop_status=loop_status)
#   File "/home/bsc0001/niftynet/lib/python3.6/site-packages/niftynet/engine/application_driver.py", line 338, in loop
#     ApplicationDriver.loop_step(application, iter_msg)
#   File "/home/bsc0001/niftynet/lib/python3.6/site-packages/niftynet/engine/application_driver.py", line 370, in loop_step
#     feed_dict=iteration_message.data_feed_dict)
#   File "/home/bsc0001/niftynet/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 887, in run
#     run_metadata_ptr)
#   File "/home/bsc0001/niftynet/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1110, in _run
#     feed_dict_tensor, options, run_metadata)
#   File "/home/bsc0001/niftynet/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1286, in _do_run
#     run_metadata)
#   File "/home/bsc0001/niftynet/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1308, in _do_call
#     raise type(e)(node_def, op, message)
# tensorflow.python.framework.errors_impl.ResourceExhaustedError: OOM when allocating tensor with shape[6,512,512,40,10] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node worker_0/gradients/worker_0/MyNet/conv_output_bn/conv_/conv_grad/Conv3DBackpropInputV2}} = Conv3DBackpropInputV2[T=DT_FLOAT, Tshape=DT_INT32, data_format="NDHWC", dilations=[1, 1, 1, 1, 1], padding="SAME", strides=[1, 1, 1, 1, 1], _device="/job:localhost/replica:0/task:0/device:GPU:0"](worker_0/gradients/worker_0/MyNet/conv_output_bn/conv_/conv_grad/Shape, MyNet/conv_output_bn/conv_/w/read, worker_0/gradients/AddN_3)]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
#
# Caused by op 'worker_0/gradients/worker_0/MyNet/conv_output_bn/conv_/conv_grad/Conv3DBackpropInputV2', defined at:
#   File "/home/bsc0001/niftynet/bin/net_segment", line 10, in <module>
#     sys.exit(main())
#   File "/home/bsc0001/niftynet/lib/python3.6/site-packages/niftynet/__init__.py", line 146, in main
#     app_driver.run(app_driver.app)
#   File "/home/bsc0001/niftynet/lib/python3.6/site-packages/niftynet/engine/application_driver.py", line 196, in run
#     is_training_action=self.is_training_action)
#   File "/home/bsc0001/niftynet/lib/python3.6/site-packages/niftynet/engine/application_driver.py", line 277, in create_graph
#     outputs_collector, gradients_collector)
#   File "/home/bsc0001/niftynet/lib/python3.6/site-packages/niftynet/application/segmentation_application.py", line 347, in connect_data_and_network
#     loss, var_list=to_optimise, colocate_gradients_with_ops=True)
#   File "/home/bsc0001/niftynet/lib/python3.6/site-packages/tensorflow/python/training/optimizer.py", line 517, in compute_gradients
#     colocate_gradients_with_ops=colocate_gradients_with_ops)
#   File "/home/bsc0001/niftynet/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py", line 596, in gradients
#     gate_gradients, aggregation_method, stop_gradients)
#   File "/home/bsc0001/niftynet/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py", line 776, in _GradientsHelper
#     lambda: grad_fn(op, *out_grads))
#   File "/home/bsc0001/niftynet/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py", line 398, in _MaybeCompile
#     return grad_fn()  # Exit early
#   File "/home/bsc0001/niftynet/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py", line 776, in <lambda>
#     lambda: grad_fn(op, *out_grads))
#   File "/home/bsc0001/niftynet/lib/python3.6/site-packages/tensorflow/python/ops/nn_grad.py", line 99, in _Conv3DGrad
#     data_format=data_format),
#   File "/home/bsc0001/niftynet/lib/python3.6/site-packages/tensorflow/python/ops/gen_nn_ops.py", line 1817, in conv3d_backprop_input_v2
#     data_format=data_format, dilations=dilations, name=name)
#   File "/home/bsc0001/niftynet/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "/home/bsc0001/niftynet/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py", line 488, in new_func
#     return func(*args, **kwargs)
#   File "/home/bsc0001/niftynet/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 3272, in create_op
#     op_def=op_def)
#   File "/home/bsc0001/niftynet/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 1768, in __init__
#     self._traceback = tf_stack.extract_stack()
#
# ...which was originally created as op 'worker_0/MyNet/conv_output_bn/conv_/conv', defined at:
#   File "/home/bsc0001/niftynet/bin/net_segment", line 10, in <module>
#     sys.exit(main())
# [elided 2 identical lines from previous traceback]
#   File "/home/bsc0001/niftynet/lib/python3.6/site-packages/niftynet/engine/application_driver.py", line 277, in create_graph
#     outputs_collector, gradients_collector)
#   File "/home/bsc0001/niftynet/lib/python3.6/site-packages/niftynet/application/segmentation_application.py", line 305, in connect_data_and_network
#     net_out = self.net(image, **net_args)
#   File "/home/bsc0001/niftynet/lib/python3.6/site-packages/niftynet/layer/base_layer.py", line 34, in __call__
#     return self._op(*args, **kwargs)
#   File "/home/bsc0001/niftynet/lib/python3.6/site-packages/tensorflow/python/ops/template.py", line 360, in __call__
#     return self._call_func(args, kwargs)
#   File "/home/bsc0001/niftynet/lib/python3.6/site-packages/tensorflow/python/ops/template.py", line 311, in _call_func
#     result = self._func(*args, **kwargs)
#   File "/home/bsc0001/niftynet/extensions/dense_vnet_TC_craneal/CNN_TC_craneal_ictus.py", line 47, in layer_op
#     flow = conv_2(flow, is_training)
#   File "/home/bsc0001/niftynet/lib/python3.6/site-packages/niftynet/layer/base_layer.py", line 34, in __call__
#     return self._op(*args, **kwargs)
#   File "/home/bsc0001/niftynet/lib/python3.6/site-packages/tensorflow/python/ops/template.py", line 360, in __call__
#     return self._call_func(args, kwargs)
#   File "/home/bsc0001/niftynet/lib/python3.6/site-packages/tensorflow/python/ops/template.py", line 311, in _call_func
#     result = self._func(*args, **kwargs)
#   File "/home/bsc0001/niftynet/lib/python3.6/site-packages/niftynet/layer/convolution.py", line 220, in layer_op
#     output_tensor = activation(conv_layer(input_tensor))
#   File "/home/bsc0001/niftynet/lib/python3.6/site-packages/niftynet/layer/base_layer.py", line 34, in __call__
#     return self._op(*args, **kwargs)
#   File "/home/bsc0001/niftynet/lib/python3.6/site-packages/tensorflow/python/ops/template.py", line 360, in __call__
#     return self._call_func(args, kwargs)
#   File "/home/bsc0001/niftynet/lib/python3.6/site-packages/tensorflow/python/ops/template.py", line 311, in _call_func
#     result = self._func(*args, **kwargs)
#
# ResourceExhaustedError (see above for traceback): OOM when allocating tensor with shape[6,512,512,40,10] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node worker_0/gradients/worker_0/MyNet/conv_output_bn/conv_/conv_grad/Conv3DBackpropInputV2}} = Conv3DBackpropInputV2[T=DT_FLOAT, Tshape=DT_INT32, data_format="NDHWC", dilations=[1, 1, 1, 1, 1], padding="SAME", strides=[1, 1, 1, 1, 1], _device="/job:localhost/replica:0/task:0/device:GPU:0"](worker_0/gradients/worker_0/MyNet/conv_output_bn/conv_/conv_grad/Shape, MyNet/conv_output_bn/conv_/w/read, worker_0/gradients/AddN_3)]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
