# %%
# %cd /home/bsc0001/niftynet
# Out:
# /home/bsc0001/niftynet

# %%
! net_segment train -c /home/bsc0001/niftynet/extensions/dense_vnet_TC_craneal/config.ini --name dense_vnet_TC_craneal.CNN_TC_craneal_ictus.MyNet
# Out:
# CRITICAL:tensorflow:Optional Python module cv2 not found, please install cv2 and retry if the application fails.
# CRITICAL:tensorflow:Optional Python module skimage.io not found, please install skimage.io and retry if the application fails.
# CRITICAL:tensorflow:Optional Python module SimpleITK not found, please install SimpleITK and retry if the application fails.
# INFO:niftynet: Optional Python module yaml not found, please install yaml and retry if the application fails.
# INFO:niftynet: Optional Python module yaml version None not found, please install yaml-None and retry if the application fails.
# INFO:niftynet: Optional Python module SimpleITK not found, please install SimpleITK and retry if the application fails.
# INFO:niftynet: Optional Python module SimpleITK version None not found, please install SimpleITK-None and retry if the application fails.
# NiftyNet version 0.5.0
# INFO:niftynet: Optional Python module yaml not found, please install yaml and retry if the application fails.
# INFO:niftynet: Optional Python module yaml version None not found, please install yaml-None and retry if the application fails.
# [CUSTOM]
# -- num_classes: 2
# -- output_prob: False
# -- label_normalisation: False
# -- softmax: True
# -- min_sampling_ratio: 0
# -- compulsory_labels: (0, 1)
# -- rand_samples: 0
# -- min_numb_labels: 1
# -- proba_connect: True
# -- evaluation_units: foreground
# -- label: ('label',)
# -- weight: ()
# -- sampler: ()
# -- inferred: ()
# -- image: ('ct',)
# -- name: net_segment
# [CONFIG_FILE]
# -- path: /home/bsc0001/niftynet/extensions/dense_vnet_TC_craneal/config.ini
# [CT]
# -- csv_file:
# -- path_to_search: ./data/dense_vnet_TC_craneal/
# -- filename_contains: ('CT',)
# -- filename_not_contains: ()
# -- filename_removefromid:
# -- interp_order: 1
# -- loader: None
# -- pixdim: ()
# -- axcodes: ('A', 'R', 'S')
# -- spatial_window_size: (512, 512, 40)
# [LABEL]
# -- csv_file:
# -- path_to_search: ./data/dense_vnet_TC_craneal/
# -- filename_contains: ('Label',)
# -- filename_not_contains: ()
# -- filename_removefromid:
# -- interp_order: 0
# -- loader: None
# -- pixdim: ()
# -- axcodes: ('A', 'R', 'S')
# -- spatial_window_size: (512, 512, 40)
# [SYSTEM]
# -- cuda_devices: ""
# -- num_threads: 1
# -- num_gpus: 1
# -- model_dir: /home/bsc0001/niftynet/models/dense_vnet_TC_craneal
# -- dataset_split_file: ./dataset_split.csv
# -- event_handler: ('model_saver', 'model_restorer', 'sampler_threading', 'apply_gradients', 'output_interpreter', 'console_logger', 'tensorboard_logger')
# -- iteration_generator: iteration_generator
# -- queue_length: 36
# -- action: training
# [NETWORK]
# -- name: dense_vnet_TC_craneal.CNN_TC_craneal_ictus.MyNet
# -- activation_function: prelu
# -- batch_size: 6
# -- smaller_final_batch_mode: pad
# -- decay: 0.0
# -- reg_type: L2
# -- volume_padding_size: (0, 0, 0)
# -- volume_padding_mode: minimum
# -- window_sampling: resize
# -- queue_length: 5
# -- multimod_foreground_type: and
# -- histogram_ref_file: ./histogram_ref_file.txt
# -- norm_type: percentile
# -- cutoff: (0.01, 0.99)
# -- foreground_type: otsu_plus
# -- normalisation: False
# -- whitening: False
# -- normalise_foreground_only: False
# -- weight_initializer: he_normal
# -- bias_initializer: zeros
# -- keep_prob: 1.0
# [TRAINING]
# -- optimiser: adam
# -- sample_per_volume: 1
# -- rotation_angle: ()
# -- rotation_angle_x: ()
# -- rotation_angle_y: ()
# -- rotation_angle_z: ()
# -- scaling_percentage: ()
# -- antialiasing: True
# -- bias_field_range: ()
# -- bf_order: 3
# -- random_flipping_axes: -1
# -- do_elastic_deformation: False
# -- num_ctrl_points: 4
# -- deformation_sigma: 15
# -- proportion_to_deform: 0.5
# -- lr: 0.001
# -- loss_type: dense_vnet_TC_craneal.dice_hinge.dice
# -- starting_iter: 0
# -- save_every_n: 1000
# -- tensorboard_every_n: 20
# -- max_iter: 3001
# -- max_checkpoints: 100
# -- validation_every_n: -1
# -- validation_max_iter: 1
# -- exclude_fraction_for_validation: 0.0
# -- exclude_fraction_for_inference: 0.0
# -- vars_to_restore:
# -- vars_to_freeze:
# [INFERENCE]
# -- spatial_window_size: (512, 512, 40)
# -- inference_iter: 3000
# -- dataset_to_infer:
# -- save_seg_dir: ./segmentation_output/
# -- output_postfix: _niftynet_out
# -- output_interp_order: 0
# -- border: (0, 0, 0)
# INFO:niftynet: starting segmentation application
# INFO:niftynet: `csv_file = ` not found, writing to "/home/bsc0001/niftynet/models/dense_vnet_TC_craneal/ct.csv" instead.
# INFO:niftynet: Overwriting existing: "/home/bsc0001/niftynet/models/dense_vnet_TC_craneal/ct.csv".
# INFO:niftynet: [ct] search file folders, writing csv file /home/bsc0001/niftynet/models/dense_vnet_TC_craneal/ct.csv
# INFO:niftynet: `csv_file = ` not found, writing to "/home/bsc0001/niftynet/models/dense_vnet_TC_craneal/label.csv" instead.
# INFO:niftynet: Overwriting existing: "/home/bsc0001/niftynet/models/dense_vnet_TC_craneal/label.csv".
# INFO:niftynet: [label] search file folders, writing csv file /home/bsc0001/niftynet/models/dense_vnet_TC_craneal/label.csv
# INFO:niftynet:
#
# Number of subjects 2, input section names: ['subject_id', 'ct', 'label']
# -- using all subjects (without data partitioning).
#
# INFO:niftynet: Image reader: loading 2 subjects from sections ('ct',) as input [image]
# INFO:niftynet: Image reader: loading 2 subjects from sections ('label',) as input [label]
# 2019-06-14 18:31:49.634778: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-06-14 18:31:51.555030: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1411] Found device 0 with properties:
# name: TITAN Xp major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:05:00.0
# totalMemory: 11.91GiB freeMemory: 11.74GiB
# 2019-06-14 18:31:51.869201: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1411] Found device 1 with properties:
# name: TITAN Xp major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:06:00.0
# totalMemory: 11.91GiB freeMemory: 11.75GiB
# 2019-06-14 18:31:52.093766: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1411] Found device 2 with properties:
# name: TITAN Xp major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:09:00.0
# totalMemory: 11.91GiB freeMemory: 11.75GiB
# 2019-06-14 18:31:52.100614: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1490] Adding visible gpu devices: 0, 1, 2
# 2019-06-14 18:31:53.654956: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-06-14 18:31:53.655028: I tensorflow/core/common_runtime/gpu/gpu_device.cc:977]      0 1 2
# 2019-06-14 18:31:53.655049: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 0:   N Y Y
# 2019-06-14 18:31:53.655067: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 1:   Y N Y
# 2019-06-14 18:31:53.655084: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 2:   Y Y N
# 2019-06-14 18:31:53.656107: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/device:GPU:0 with 11361 MB memory) -> physical GPU (device: 0, name: TITAN Xp, pci bus id: 0000:05:00.0, compute capability: 6.1)
# 2019-06-14 18:31:54.007592: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/device:GPU:1 with 11363 MB memory) -> physical GPU (device: 1, name: TITAN Xp, pci bus id: 0000:06:00.0, compute capability: 6.1)
# 2019-06-14 18:31:54.486348: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/device:GPU:2 with 11363 MB memory) -> physical GPU (device: 2, name: TITAN Xp, pci bus id: 0000:09:00.0, compute capability: 6.1)
# INFO:niftynet: reading size of preprocessed images
# WARNING:niftynet: sampler queue_length should be larger than batch_size, defaulting to batch_size * 5.0 (30).
# INFO:niftynet: initialised resize sampler {'image': (1, 512, 512, 40, 1, 1), 'image_location': (1, 7), 'label': (1, 512, 512, 40, 1, 1), 'label_location': (1, 7)}
# INFO:niftynet: Import [MyNet] from /home/bsc0001/niftynet/extensions/dense_vnet_TC_craneal/CNN_TC_craneal_ictus.py.
# WARNING:niftynet: From /home/bsc0001/niftynet/lib/python3.6/site-packages/niftynet/engine/application_initializer.py:106: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with distribution=normal is deprecated and will be removed in a future version.
# Instructions for updating:
# `normal` is a deprecated alias for `truncated_normal`
# Traceback (most recent call last):
#   File "/home/bsc0001/niftynet/bin/net_segment", line 10, in <module>
#     sys.exit(main())
#   File "/home/bsc0001/niftynet/lib/python3.6/site-packages/niftynet/__init__.py", line 142, in main
#     app_driver.run(app_driver.app)
#   File "/home/bsc0001/niftynet/lib/python3.6/site-packages/niftynet/engine/application_driver.py", line 189, in run
#     is_training_action=self.is_training_action)
#   File "/home/bsc0001/niftynet/lib/python3.6/site-packages/niftynet/engine/application_driver.py", line 258, in create_graph
#     application.initialise_network()
#   File "/home/bsc0001/niftynet/lib/python3.6/site-packages/niftynet/application/segmentation_application.py", line 280, in initialise_network
#     acti_func=self.net_param.activation_function)
# TypeError: __init__() got an unexpected keyword argument 'w_initializer'
