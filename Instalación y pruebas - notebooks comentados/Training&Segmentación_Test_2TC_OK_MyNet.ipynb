# %%
# %cd /home/bsc0001/niftynet
# Out:
# /home/bsc0001/niftynet

# %%
# !pip install SimpleITK
# !pip install pyyaml

# %%
! net_segment train -c /home/bsc0001/niftynet/extensions/dense_vnet_TC_craneal/config.ini --name dense_vnet_TC_craneal.CNN_TC_craneal_ictus.MyNet
# Out:
# CRITICAL:tensorflow:Optional Python module cv2 not found, please install cv2 and retry if the application fails.
# CRITICAL:tensorflow:Optional Python module skimage.io not found, please install skimage.io and retry if the application fails.
# NiftyNet version 0.5.0
# [CUSTOM]
# -- num_classes: 2
# -- output_prob: False
# -- label_normalisation: False
# -- softmax: True
# -- min_sampling_ratio: 0
# -- compulsory_labels: (0, 1)
# -- rand_samples: 0
# -- min_numb_labels: 1
# -- proba_connect: True
# -- evaluation_units: foreground
# -- weight: ()
# -- sampler: ()
# -- inferred: ()
# -- label: ('label',)
# -- image: ('ct',)
# -- name: net_segment
# [CONFIG_FILE]
# -- path: /home/bsc0001/niftynet/extensions/dense_vnet_TC_craneal/config.ini
# [CT]
# -- csv_file:
# -- path_to_search: ./data/dense_vnet_TC_craneal/
# -- filename_contains: ('TC',)
# -- filename_not_contains: ()
# -- filename_removefromid:
# -- interp_order: 1
# -- loader: None
# -- pixdim: ()
# -- axcodes: ('A', 'R', 'S')
# -- spatial_window_size: (512, 512, 40)
# [LABEL]
# -- csv_file:
# -- path_to_search: ./data/dense_vnet_TC_craneal/
# -- filename_contains: ('mask',)
# -- filename_not_contains: ()
# -- filename_removefromid:
# -- interp_order: 0
# -- loader: None
# -- pixdim: ()
# -- axcodes: ('A', 'R', 'S')
# -- spatial_window_size: (512, 512, 40)
# [SYSTEM]
# -- cuda_devices: ""
# -- num_threads: 3
# -- num_gpus: 3
# -- model_dir: /home/bsc0001/niftynet/models/dense_vnet_TC_craneal
# -- dataset_split_file: ./dataset_split.csv
# -- event_handler: ('model_saver', 'model_restorer', 'sampler_threading', 'apply_gradients', 'output_interpreter', 'console_logger', 'tensorboard_logger')
# -- iteration_generator: iteration_generator
# -- action: training
# [NETWORK]
# -- name: dense_vnet_TC_craneal.CNN_TC_craneal_ictus.MyNet
# -- activation_function: relu
# -- batch_size: 2
# -- smaller_final_batch_mode: pad
# -- decay: 0.0
# -- reg_type: L2
# -- volume_padding_size: (0, 0, 0)
# -- volume_padding_mode: minimum
# -- window_sampling: resize
# -- queue_length: 12
# -- multimod_foreground_type: and
# -- histogram_ref_file: ./histogram_ref_file.txt
# -- norm_type: percentile
# -- cutoff: (0.01, 0.99)
# -- foreground_type: otsu_plus
# -- normalisation: False
# -- whitening: False
# -- normalise_foreground_only: False
# -- weight_initializer: he_normal
# -- bias_initializer: zeros
# -- keep_prob: 1.0
# -- weight_initializer_args: {}
# -- bias_initializer_args: {}
# [TRAINING]
# -- optimiser: adam
# -- sample_per_volume: 1
# -- rotation_angle: ()
# -- rotation_angle_x: ()
# -- rotation_angle_y: ()
# -- rotation_angle_z: ()
# -- scaling_percentage: ()
# -- antialiasing: True
# -- bias_field_range: ()
# -- bf_order: 3
# -- random_flipping_axes: -1
# -- do_elastic_deformation: False
# -- num_ctrl_points: 4
# -- deformation_sigma: 15
# -- proportion_to_deform: 0.5
# -- lr: 0.001
# -- loss_type: dense_vnet_TC_craneal.dice_hinge.dice
# -- starting_iter: 0
# -- save_every_n: 10
# -- tensorboard_every_n: 20
# -- max_iter: 31
# -- max_checkpoints: 100
# -- validation_every_n: -1
# -- validation_max_iter: 1
# -- exclude_fraction_for_validation: 0.0
# -- exclude_fraction_for_inference: 0.0
# -- vars_to_restore:
# -- vars_to_freeze:
# [INFERENCE]
# -- spatial_window_size: (512, 512, 40)
# -- inference_iter: 30
# -- dataset_to_infer:
# -- save_seg_dir: ./segmentation_output/
# -- output_postfix: _niftynet_out
# -- output_interp_order: 0
# -- border: (0, 0, 0)
# INFO:niftynet: starting segmentation application
# INFO:niftynet: `csv_file = ` not found, writing to "/home/bsc0001/niftynet/models/dense_vnet_TC_craneal/ct.csv" instead.
# INFO:niftynet: Overwriting existing: "/home/bsc0001/niftynet/models/dense_vnet_TC_craneal/ct.csv".
# INFO:niftynet: [ct] search file folders, writing csv file /home/bsc0001/niftynet/models/dense_vnet_TC_craneal/ct.csv
# INFO:niftynet: `csv_file = ` not found, writing to "/home/bsc0001/niftynet/models/dense_vnet_TC_craneal/label.csv" instead.
# INFO:niftynet: Overwriting existing: "/home/bsc0001/niftynet/models/dense_vnet_TC_craneal/label.csv".
# INFO:niftynet: [label] search file folders, writing csv file /home/bsc0001/niftynet/models/dense_vnet_TC_craneal/label.csv
# INFO:niftynet:
#
# Number of subjects 2, input section names: ['subject_id', 'ct', 'label']
# -- using all subjects (without data partitioning).
#
# INFO:niftynet: Image reader: loading 2 subjects from sections ('ct',) as input [image]
# INFO:niftynet: Image reader: loading 2 subjects from sections ('label',) as input [label]
# 2019-06-18 15:13:00.180486: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-06-18 15:13:01.618667: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1411] Found device 0 with properties:
# name: TITAN Xp major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:05:00.0
# totalMemory: 11.91GiB freeMemory: 11.74GiB
# 2019-06-18 15:13:01.791799: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1411] Found device 1 with properties:
# name: TITAN Xp major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:06:00.0
# totalMemory: 11.91GiB freeMemory: 11.75GiB
# 2019-06-18 15:13:01.950091: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1411] Found device 2 with properties:
# name: TITAN Xp major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:09:00.0
# totalMemory: 11.91GiB freeMemory: 11.75GiB
# 2019-06-18 15:13:01.954666: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1490] Adding visible gpu devices: 0, 1, 2
# 2019-06-18 15:13:02.742731: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-06-18 15:13:02.742765: I tensorflow/core/common_runtime/gpu/gpu_device.cc:977]      0 1 2
# 2019-06-18 15:13:02.742789: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 0:   N Y Y
# 2019-06-18 15:13:02.742796: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 1:   Y N Y
# 2019-06-18 15:13:02.742802: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 2:   Y Y N
# 2019-06-18 15:13:02.743509: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/device:GPU:0 with 11361 MB memory) -> physical GPU (device: 0, name: TITAN Xp, pci bus id: 0000:05:00.0, compute capability: 6.1)
# 2019-06-18 15:13:02.896753: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/device:GPU:1 with 11363 MB memory) -> physical GPU (device: 1, name: TITAN Xp, pci bus id: 0000:06:00.0, compute capability: 6.1)
# 2019-06-18 15:13:03.050326: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/device:GPU:2 with 11363 MB memory) -> physical GPU (device: 2, name: TITAN Xp, pci bus id: 0000:09:00.0, compute capability: 6.1)
# INFO:niftynet: reading size of preprocessed images
# INFO:niftynet: initialised resize sampler {'image': (1, 512, 512, 40, 1, 1), 'image_location': (1, 7), 'label': (1, 512, 512, 40, 1, 1), 'label_location': (1, 7)}
#
# Usando my Red
#
# INFO:niftynet: Import [MyNet] from /home/bsc0001/niftynet/extensions/dense_vnet_TC_craneal/CNN_TC_craneal_ictus.py.
# WARNING:niftynet: From /home/bsc0001/niftynet/lib/python3.6/site-packages/niftynet/engine/application_initializer.py:106: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with distribution=normal is deprecated and will be removed in a future version.
# Instructions for updating:
# `normal` is a deprecated alias for `truncated_normal`
# INFO:niftynet: using MyNet
# 2019-06-18 15:13:03.260648: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1490] Adding visible gpu devices: 0, 1, 2
# 2019-06-18 15:13:03.260788: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-06-18 15:13:03.260798: I tensorflow/core/common_runtime/gpu/gpu_device.cc:977]      0 1 2
# 2019-06-18 15:13:03.260805: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 0:   N Y Y
# 2019-06-18 15:13:03.260811: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 1:   Y N Y
# 2019-06-18 15:13:03.260817: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 2:   Y Y N
# 2019-06-18 15:13:03.261139: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/device:GPU:0 with 11361 MB memory) -> physical GPU (device: 0, name: TITAN Xp, pci bus id: 0000:05:00.0, compute capability: 6.1)
# 2019-06-18 15:13:03.261430: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/device:GPU:1 with 11363 MB memory) -> physical GPU (device: 1, name: TITAN Xp, pci bus id: 0000:06:00.0, compute capability: 6.1)
# 2019-06-18 15:13:03.261619: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/device:GPU:2 with 11363 MB memory) -> physical GPU (device: 2, name: TITAN Xp, pci bus id: 0000:09:00.0, compute capability: 6.1)
# INFO:niftynet: Initialising Dataset from 2 subjects...
# INFO:niftynet: Import [dice] from /home/bsc0001/niftynet/extensions/dense_vnet_TC_craneal/dice_hinge.py.
# 2019-06-18 15:13:04.204182: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1490] Adding visible gpu devices: 0, 1, 2
# 2019-06-18 15:13:04.204338: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-06-18 15:13:04.204350: I tensorflow/core/common_runtime/gpu/gpu_device.cc:977]      0 1 2
# 2019-06-18 15:13:04.204358: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 0:   N Y Y
# 2019-06-18 15:13:04.204364: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 1:   Y N Y
# 2019-06-18 15:13:04.204370: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 2:   Y Y N
# 2019-06-18 15:13:04.204676: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/device:GPU:0 with 11361 MB memory) -> physical GPU (device: 0, name: TITAN Xp, pci bus id: 0000:05:00.0, compute capability: 6.1)
# 2019-06-18 15:13:04.204917: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/device:GPU:1 with 11363 MB memory) -> physical GPU (device: 1, name: TITAN Xp, pci bus id: 0000:06:00.0, compute capability: 6.1)
# 2019-06-18 15:13:04.205119: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/device:GPU:2 with 11363 MB memory) -> physical GPU (device: 2, name: TITAN Xp, pci bus id: 0000:09:00.0, compute capability: 6.1)
# INFO:niftynet: Import [dice] from /home/bsc0001/niftynet/extensions/dense_vnet_TC_craneal/dice_hinge.py.
# 2019-06-18 15:13:04.962577: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1490] Adding visible gpu devices: 0, 1, 2
# 2019-06-18 15:13:04.962699: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-06-18 15:13:04.962711: I tensorflow/core/common_runtime/gpu/gpu_device.cc:977]      0 1 2
# 2019-06-18 15:13:04.962719: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 0:   N Y Y
# 2019-06-18 15:13:04.962725: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 1:   Y N Y
# 2019-06-18 15:13:04.962731: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 2:   Y Y N
# 2019-06-18 15:13:04.963003: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/device:GPU:0 with 11361 MB memory) -> physical GPU (device: 0, name: TITAN Xp, pci bus id: 0000:05:00.0, compute capability: 6.1)
# 2019-06-18 15:13:04.963218: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/device:GPU:1 with 11363 MB memory) -> physical GPU (device: 1, name: TITAN Xp, pci bus id: 0000:06:00.0, compute capability: 6.1)
# 2019-06-18 15:13:04.963407: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/device:GPU:2 with 11363 MB memory) -> physical GPU (device: 2, name: TITAN Xp, pci bus id: 0000:09:00.0, compute capability: 6.1)
# INFO:niftynet: Import [dice] from /home/bsc0001/niftynet/extensions/dense_vnet_TC_craneal/dice_hinge.py.
# 2019-06-18 15:13:06.475212: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1490] Adding visible gpu devices: 0, 1, 2
# 2019-06-18 15:13:06.475356: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-06-18 15:13:06.475368: I tensorflow/core/common_runtime/gpu/gpu_device.cc:977]      0 1 2
# 2019-06-18 15:13:06.475375: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 0:   N Y Y
# 2019-06-18 15:13:06.475381: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 1:   Y N Y
# 2019-06-18 15:13:06.475387: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 2:   Y Y N
# 2019-06-18 15:13:06.475688: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 11361 MB memory) -> physical GPU (device: 0, name: TITAN Xp, pci bus id: 0000:05:00.0, compute capability: 6.1)
# 2019-06-18 15:13:06.475890: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 11363 MB memory) -> physical GPU (device: 1, name: TITAN Xp, pci bus id: 0000:06:00.0, compute capability: 6.1)
# 2019-06-18 15:13:06.476089: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:2 with 11363 MB memory) -> physical GPU (device: 2, name: TITAN Xp, pci bus id: 0000:09:00.0, compute capability: 6.1)
# INFO:niftynet: Parameters from random initialisations ...
# dice[0.872955 0]
# dice[0.872955 0]
# dice[0.872955 0]
# dice[0.772152603 0.0647273585]
# dice[0.772152603 0.0647273585]
# dice[0.772152603 0.0647273585]
# INFO:niftynet: training iter 1, loss=5.883581161499023, loss_1=5.883581161499023, loss_2=5.883581161499023 (34.464526s)
# dice[0.863697231 0]
# dice[0.864797294 0.0796862766]
# dice[0.791756392 0.0682485849]
# dice[0.784734368 0]
# dice[0.772379816 0]
# dice[0.778163 0.0631976426]
# INFO:niftynet: training iter 2, loss=5.843941688537598, loss_1=0.9953041672706604, loss_2=10.587892532348633 (15.791245s)
# dice[0.867342114 0]
# dice[0.791440427 0.0680041835]
# dice[0.857323289 0.0816530511]
# dice[0.774669 0]
# dice[0.775569618 0]
# dice[0.767315686 0.0624000467]
# INFO:niftynet: training iter 3, loss=5.847404479980469, loss_1=5.929174423217773, loss_2=5.655516147613525 (16.224653s)
# dice[0.863549769 0]
# dice[0.864280283 0.0817286819]
# dice[0.790483892 0.0695708618]
# dice[0.774756491 0]
# dice[0.777120173 0]
# dice[0.767072618 0.0636949]
# INFO:niftynet: training iter 4, loss=5.8221893310546875, loss_1=0.9687812328338623, loss_2=10.590423583984375 (15.939341s)
# dice[0.874278188 0]
# dice[0.871938527 0.0821374878]
# dice[0.794109881 0.0684031323]
# dice[0.765690625 0.0661547258]
# dice[0.765399635 0.0693198815]
# dice[0.774928689 0.0752366707]
# INFO:niftynet: training iter 5, loss=0.9747264981269836, loss_1=5.85984468460083, loss_2=0.8678858280181885 (17.429147s)
# dice[0.801252484 0]
# dice[0.872625053 0]
# dice[0.86944443 0.0802376643]
# dice[0.779200673 0]
# dice[0.772535622 0]
# dice[0.769841671 0]
# INFO:niftynet: training iter 6, loss=10.604887008666992, loss_1=10.588709831237793, loss_2=5.6677565574646 (14.697154s)
# dice[0.882962525 0]
# dice[0.882962525 0]
# dice[0.873911679 0.0793551281]
# dice[0.77056396 0]
# dice[0.766941667 0.0683203638]
# dice[0.766941667 0.0683203638]
# INFO:niftynet: training iter 7, loss=5.821343898773193, loss_1=5.675594806671143, loss_2=5.821343898773193 (12.835458s)
# dice[0.887306869 0]
# dice[0.884135365 0.0828964338]
# dice[0.878883302 0.0831470042]
# dice[0.768318772 0]
# dice[0.766201437 0.0698264092]
# dice[0.763585448 0.0695857555]
# INFO:niftynet: training iter 8, loss=5.796777725219727, loss_1=5.638418674468994, loss_2=0.8543388843536377 (15.885439s)
# dice[0.885947049 0]
# dice[0.83099848 0]
# dice[0.884560168 0.0821742266]
# dice[0.769950926 0]
# dice[0.764410853 0.071283482]
# dice[0.765657187 0]
# INFO:niftynet: training iter 9, loss=5.646341323852539, loss_1=5.789486885070801, loss_2=10.58602523803711 (12.601199s)
# dice[0.796626091 0.0708471388]
# dice[0.829939067 0.0834645778]
# dice[0.830268085 0.083763428]
# dice[0.785851896 0.0743275136]
# dice[0.758528769 0.0763110667]
# dice[0.759342313 0.0763743669]
# INFO:niftynet: iter 10 saved: /home/bsc0001/niftynet/models/dense_vnet_TC_craneal/models/model.ckpt
# INFO:niftynet: training iter 10, loss=0.9453282356262207, loss_1=0.7706176042556763, loss_2=0.7689801454544067 (17.669503s)
# dice[0.834375143 0]
# dice[0.7982651 0.0712380782]
# dice[0.831839383 0.0803388208]
# dice[0.766279876 0]
# dice[0.791277 0]
# dice[0.760852 0]
# INFO:niftynet: training iter 11, loss=5.791616916656494, loss_1=5.678382873535156, loss_2=10.599836349487305 (16.207095s)
# dice[0.836263299 0.0795481652]
# dice[0.800580859 0.0694461688]
# dice[0.833392918 0.0823045596]
# dice[0.758414924 0]
# dice[0.793623388 0]
# dice[0.758667111 0]
# INFO:niftynet: training iter 12, loss=5.817471504211426, loss_1=5.659690856933594, loss_2=5.6860127449035645 (12.898709s)
# dice[0.805320323 0]
# dice[0.843998194 0.0782569945]
# dice[0.839310646 0.0787173286]
# dice[0.793971837 0]
# dice[0.755150497 0]
# dice[0.753240645 0.0816091672]
# INFO:niftynet: training iter 13, loss=10.600176811218262, loss_1=0.7634689807891846, loss_2=5.694943428039551 (14.214014s)
# dice[0.845451593 0]
# dice[0.846405864 0]
# dice[0.800326526 0.0693048686]
# dice[0.746435285 0]
# dice[0.758919597 0.079458]
# dice[0.793559253 0.0730893239]
# INFO:niftynet: training iter 14, loss=0.9825237989425659, loss_1=5.684297561645508, loss_2=10.602027893066406 (13.745079s)
# dice[0.848791 0]
# dice[0.805961251 0]
# dice[0.85170877 0.0772018582]
# dice[0.798469663 0]
# dice[0.744838119 0]
# dice[0.750736058 0.0837414861]
# INFO:niftynet: training iter 15, loss=10.598892211914062, loss_1=10.601593017578125, loss_2=0.7551766633987427 (14.675298s)
# dice[0.857104778 0]
# dice[0.806453228 0]
# dice[0.85150969 0.0769859]
# dice[0.747944653 0]
# dice[0.79730171 0.0725011826]
# dice[0.754416168 0.0850238]
# INFO:niftynet: training iter 16, loss=5.76998233795166, loss_1=5.631935119628906, loss_2=5.713302135467529 (16.541009s)
# dice[0.850808918 0]
# dice[0.808893502 0]
# dice[0.853688717 0.0791254565]
# dice[0.739414394 0]
# dice[0.799336791 0.0721793]
# dice[0.746615946 0.0821730345]
# INFO:niftynet: training iter 17, loss=5.773395538330078, loss_1=0.7479859590530396, loss_2=10.60244369506836 (15.783419s)
# dice[0.856532872 0]
# dice[0.852305293 0.0765996873]
# dice[0.852305293 0.0765996873]
# dice[0.745084465 0]
# dice[0.752540946 0.0860993415]
# dice[0.745084465 0]
# INFO:niftynet: training iter 18, loss=5.624513626098633, loss_1=5.718396186828613, loss_2=5.718396186828613 (16.456504s)
# dice[0.854706526 0]
# dice[0.80226177 0.0667460859]
# dice[0.859167218 0.0758638531]
# dice[0.739609957 0]
# dice[0.807664 0]
# dice[0.751564622 0.086034745]
# INFO:niftynet: training iter 19, loss=5.857287883758545, loss_1=0.7512378692626953, loss_2=10.601421356201172 (15.978770s)
# dice[0.861802042 0]
# dice[0.85774225 0]
# dice[0.85774225 0]
# dice[0.748772085 0]
# dice[0.748772085 0]
# dice[0.75589931 0.0867001861]
# INFO:niftynet: iter 20 saved: /home/bsc0001/niftynet/models/dense_vnet_TC_craneal/models/model.ckpt
# INFO:niftynet: training iter 20, loss=10.598371505737305, loss_1=10.598371505737305, loss_2=5.618121147155762 (22.568496s)
# dice[0.86437732 0]
# dice[0.862314343 0.0767777115]
# dice[0.803176641 0.0671792626]
# dice[0.747318208 0]
# dice[0.757777154 0.0871410295]
# dice[0.812192559 0]
# INFO:niftynet: training iter 21, loss=5.848662853240967, loss_1=5.713216304779053, loss_2=5.614014625549316 (12.940980s)
# dice[0.866789341 0]
# dice[0.804560542 0.0671151578]
# dice[0.857703745 0.0800557286]
# dice[0.75241971 0]
# dice[0.760735929 0.0872003]
# dice[0.810704768 0.0706930235]
# INFO:niftynet: training iter 22, loss=1.0468095541000366, loss_1=5.612277030944824, loss_2=5.676898956298828 (13.525882s)
# dice[0.860115409 0]
# dice[0.868249476 0]
# dice[0.866733193 0.0778486356]
# dice[0.750175893 0]
# dice[0.764903963 0.0869797617]
# dice[0.767537 0.0842958689]
# INFO:niftynet: training iter 23, loss=5.698981285095215, loss_1=5.633667945861816, loss_2=5.6123480796813965 (16.254547s)
# dice[0.811841 0]
# dice[0.869476199 0.0785154477]
# dice[0.869476199 0.0785154477]
# dice[0.750259221 0]
# dice[0.750259221 0]
# dice[0.814478755 0.069968611]
# INFO:niftynet: training iter 24, loss=5.801399230957031, loss_1=5.690833568572998, loss_2=5.690833568572998 (16.570988s)
# dice[0.869387925 0]
# dice[0.860643446 0]
# dice[0.870955229 0.0795771554]
# dice[0.747416914 0]
# dice[0.756601095 0.0874835]
# dice[0.74108392 0]
# INFO:niftynet: training iter 25, loss=5.61079740524292, loss_1=10.597984313964844, loss_2=5.681368827819824 (16.215337s)
# dice[0.869065464 0]
# dice[0.869065464 0]
# dice[0.871433437 0.0806192458]
# dice[0.743597329 0]
# dice[0.760027 0.0946213678]
# dice[0.760027 0.0946213678]
# INFO:niftynet: training iter 26, loss=5.5763044357299805, loss_1=5.6699910163879395, loss_2=5.5763044357299805 (12.903208s)
# dice[0.859667361 0.0833647847]
# dice[0.872072399 0.0817009807]
# dice[0.872072399 0.0817009807]
# dice[0.747680187 0]
# dice[0.747680187 0]
# dice[0.760986507 0.0919640437]
# INFO:niftynet: training iter 27, loss=5.658349990844727, loss_1=0.6363310813903809, loss_2=5.658349990844727 (16.049515s)
# dice[0.866426528 0]
# dice[0.853662968 0]
# dice[0.870209277 0.0826455727]
# dice[0.750783861 0]
# dice[0.748511612 0]
# dice[0.772964239 0.0921006724]
# INFO:niftynet: training iter 28, loss=10.595697402954102, loss_1=5.649952411651611, loss_2=5.585917949676514 (14.127452s)
# dice[0.864609957 0]
# dice[0.863049567 0]
# dice[0.869559824 0.0833531618]
# dice[0.739309251 0]
# dice[0.754768252 0.095085]
# dice[0.736895 0]
# INFO:niftynet: training iter 29, loss=10.599020004272461, loss_1=5.646827220916748, loss_2=5.577813625335693 (14.102702s)
# dice[0.866999805 0]
# dice[0.872377217 0.0810476765]
# dice[0.872377217 0.0810476765]
# dice[0.754822135 0.0964232236]
# dice[0.747886598 0.0954329297]
# dice[0.747886598 0.0954329297]
# INFO:niftynet: iter 30 saved: /home/bsc0001/niftynet/models/dense_vnet_TC_craneal/models/model.ckpt
# INFO:niftynet: training iter 30, loss=0.6458260416984558, loss_1=5.573637008666992, loss_2=0.6458260416984558 (14.190837s)
# dice[0.808253169 0]
# dice[0.857520819 0]
# dice[0.860230148 0.0834371895]
# dice[0.82973963 0]
# dice[0.73416537 0]
# dice[0.741584241 0.092707552]
# INFO:niftynet: training iter 31, loss=10.59050178527832, loss_1=0.6373867988586426, loss_2=10.602078437805176 (14.621219s)
# INFO:niftynet: cleaning up...
# INFO:niftynet: iter 31 saved: /home/bsc0001/niftynet/models/dense_vnet_TC_craneal/models/model.ckpt
# INFO:niftynet: stopping sampling threads
# INFO:niftynet: SegmentationApplication stopped (time in second 495.56).

# %%
# !ls /home/bsc0001/niftynet/models/dense_vnet_TC_craneal/models
# Out:
# checkpoint			   model.ckpt-30.data-00000-of-00001
# model.ckpt-10.data-00000-of-00001  model.ckpt-30.index
# model.ckpt-10.index		   model.ckpt-30.meta
# model.ckpt-10.meta		   model.ckpt-31.data-00000-of-00001
# model.ckpt-20.data-00000-of-00001  model.ckpt-31.index
# model.ckpt-20.index		   model.ckpt-31.meta
# model.ckpt-20.meta

# %%
# Segmentar utilizando los datos del entrenamiento, desde la configuración inicial.
! net_segment inference -c ~/niftynet/extensions/dense_vnet_TC_craneal/config.ini
# Out:
# CRITICAL:tensorflow:Optional Python module cv2 not found, please install cv2 and retry if the application fails.
# CRITICAL:tensorflow:Optional Python module skimage.io not found, please install skimage.io and retry if the application fails.
# NiftyNet version 0.5.0
# [CUSTOM]
# -- num_classes: 2
# -- output_prob: False
# -- label_normalisation: False
# -- softmax: True
# -- min_sampling_ratio: 0
# -- compulsory_labels: (0, 1)
# -- rand_samples: 0
# -- min_numb_labels: 1
# -- proba_connect: True
# -- evaluation_units: foreground
# -- weight: ()
# -- inferred: ()
# -- label: ('label',)
# -- image: ('ct',)
# -- sampler: ()
# -- name: net_segment
# [CONFIG_FILE]
# -- path: /home/bsc0001/niftynet/extensions/dense_vnet_TC_craneal/config.ini
# [CT]
# -- csv_file:
# -- path_to_search: ./data/dense_vnet_TC_craneal/
# -- filename_contains: ('TC',)
# -- filename_not_contains: ()
# -- filename_removefromid:
# -- interp_order: 1
# -- loader: None
# -- pixdim: ()
# -- axcodes: ('A', 'R', 'S')
# -- spatial_window_size: (512, 512, 40)
# [LABEL]
# -- csv_file:
# -- path_to_search: ./data/dense_vnet_TC_craneal/
# -- filename_contains: ('mask',)
# -- filename_not_contains: ()
# -- filename_removefromid:
# -- interp_order: 0
# -- loader: None
# -- pixdim: ()
# -- axcodes: ('A', 'R', 'S')
# -- spatial_window_size: (512, 512, 40)
# [SYSTEM]
# -- cuda_devices: ""
# -- num_threads: 1
# -- num_gpus: 1
# -- model_dir: /home/bsc0001/niftynet/models/dense_vnet_TC_craneal
# -- dataset_split_file: ./dataset_split.csv
# -- event_handler: ('model_saver', 'model_restorer', 'sampler_threading', 'apply_gradients', 'output_interpreter', 'console_logger', 'tensorboard_logger')
# -- iteration_generator: iteration_generator
# -- batch_size: 2
# -- queue_length: 12
# -- action: inference
# [NETWORK]
# -- name: dense_vnet_TC_craneal.CNN_TC_craneal_ictus.MyNet
# -- activation_function: relu
# -- batch_size: 2
# -- smaller_final_batch_mode: pad
# -- decay: 0.0
# -- reg_type: L2
# -- volume_padding_size: (0, 0, 0)
# -- volume_padding_mode: minimum
# -- window_sampling: resize
# -- queue_length: 12
# -- multimod_foreground_type: and
# -- histogram_ref_file: ./histogram_ref_file.txt
# -- norm_type: percentile
# -- cutoff: (0.01, 0.99)
# -- foreground_type: otsu_plus
# -- normalisation: False
# -- whitening: False
# -- normalise_foreground_only: False
# -- weight_initializer: he_normal
# -- bias_initializer: zeros
# -- keep_prob: 1.0
# -- weight_initializer_args: {}
# -- bias_initializer_args: {}
# [TRAINING]
# -- optimiser: adam
# -- sample_per_volume: 1
# -- rotation_angle: ()
# -- rotation_angle_x: ()
# -- rotation_angle_y: ()
# -- rotation_angle_z: ()
# -- scaling_percentage: ()
# -- antialiasing: True
# -- bias_field_range: ()
# -- bf_order: 3
# -- random_flipping_axes: -1
# -- do_elastic_deformation: False
# -- num_ctrl_points: 4
# -- deformation_sigma: 15
# -- proportion_to_deform: 0.5
# -- lr: 0.001
# -- loss_type: dense_vnet_TC_craneal.dice_hinge.dice
# -- starting_iter: 0
# -- save_every_n: 10
# -- tensorboard_every_n: 20
# -- max_iter: 31
# -- max_checkpoints: 100
# -- validation_every_n: -1
# -- validation_max_iter: 1
# -- exclude_fraction_for_validation: 0.0
# -- exclude_fraction_for_inference: 0.0
# -- vars_to_restore: ^.*(conv_1|conv_2).*$
# -- vars_to_freeze:
# [INFERENCE]
# -- spatial_window_size: (512, 512, 40)
# -- inference_iter: 30
# -- dataset_to_infer:
# -- save_seg_dir: ./segmentation_output/
# -- output_postfix: _niftynet_out
# -- output_interp_order: 0
# -- border: (0, 0, 0)
# INFO:niftynet: starting segmentation application
# INFO:niftynet: `csv_file = ` not found, writing to "/home/bsc0001/niftynet/models/dense_vnet_TC_craneal/ct.csv" instead.
# INFO:niftynet: Overwriting existing: "/home/bsc0001/niftynet/models/dense_vnet_TC_craneal/ct.csv".
# INFO:niftynet: [ct] search file folders, writing csv file /home/bsc0001/niftynet/models/dense_vnet_TC_craneal/ct.csv
# INFO:niftynet: `csv_file = ` not found, writing to "/home/bsc0001/niftynet/models/dense_vnet_TC_craneal/label.csv" instead.
# INFO:niftynet: Overwriting existing: "/home/bsc0001/niftynet/models/dense_vnet_TC_craneal/label.csv".
# INFO:niftynet: [label] search file folders, writing csv file /home/bsc0001/niftynet/models/dense_vnet_TC_craneal/label.csv
# INFO:niftynet:
#
# Number of subjects 2, input section names: ['subject_id', 'ct', 'label']
# -- using all subjects (without data partitioning).
#
# INFO:niftynet: Image reader: loading 2 subjects from sections ('ct',) as input [image]
#
# system_param:  {'SYSTEM': Namespace(action='inference', batch_size='2', cuda_devices='""', dataset_split_file='/home/bsc0001/niftynet/models/dense_vnet_TC_craneal/dataset_split.csv', event_handler=('model_saver', 'model_restorer', 'sampler_threading', 'apply_gradients', 'output_interpreter', 'console_logger', 'tensorboard_logger'), iteration_generator='iteration_generator', model_dir='/home/bsc0001/niftynet/models/dense_vnet_TC_craneal', num_gpus=1, num_threads=1, queue_length='12'), 'NETWORK': Namespace(activation_function='relu', batch_size=2, bias_initializer='zeros', bias_initializer_args={}, cutoff=(0.01, 0.99), decay=0.0, foreground_type='otsu_plus', histogram_ref_file='/home/bsc0001/niftynet/models/dense_vnet_TC_craneal/histogram_ref_file.txt', keep_prob=1.0, multimod_foreground_type='and', name='dense_vnet_TC_craneal.CNN_TC_craneal_ictus.MyNet', norm_type='percentile', normalisation=False, normalise_foreground_only=False, queue_length=12, reg_type='L2', smaller_final_batch_mode='pad', volume_padding_mode='minimum', volume_padding_size=(0, 0, 0), weight_initializer='he_normal', weight_initializer_args={}, whitening=False, window_sampling='resize'), 'TRAINING': Namespace(antialiasing=True, bf_order=3, bias_field_range=(), deformation_sigma=15, do_elastic_deformation=False, exclude_fraction_for_inference=0.0, exclude_fraction_for_validation=0.0, loss_type='dense_vnet_TC_craneal.dice_hinge.dice', lr=0.001, max_checkpoints=100, max_iter=31, num_ctrl_points=4, optimiser='adam', proportion_to_deform=0.5, random_flipping_axes=-1, rotation_angle=(), rotation_angle_x=(), rotation_angle_y=(), rotation_angle_z=(), sample_per_volume=1, save_every_n=10, scaling_percentage=(), starting_iter=0, tensorboard_every_n=20, validation_every_n=-1, validation_max_iter=1, vars_to_freeze='', vars_to_restore='^.*(conv_1|conv_2).*$'), 'INFERENCE': Namespace(border=(0, 0, 0), dataset_to_infer='', inference_iter=30, output_interp_order=0, output_postfix='_niftynet_out', save_seg_dir='/home/bsc0001/niftynet/models/dense_vnet_TC_craneal/segmentation_output', spatial_window_size=(512, 512, 40)), 'CUSTOM': Namespace(compulsory_labels=(0, 1), evaluation_units='foreground', image=('ct',), inferred=(), label=('label',), label_normalisation=False, min_numb_labels=1, min_sampling_ratio=0, name='net_segment', num_classes=2, output_prob=False, proba_connect=True, rand_samples=0, sampler=(), softmax=True, weight=()), 'CONFIG_FILE': Namespace(path='/home/bsc0001/niftynet/extensions/dense_vnet_TC_craneal/config.ini')}
#
# input_data_param: {'ct': Namespace(axcodes=('A', 'R', 'S'), csv_file='', filename_contains=('TC',), filename_not_contains=(), filename_removefromid='', interp_order=1, loader=None, path_to_search='./data/dense_vnet_TC_craneal/', pixdim=(), spatial_window_size=(512, 512, 40)), 'label': Namespace(axcodes=('A', 'R', 'S'), csv_file='', filename_contains=('mask',), filename_not_contains=(), filename_removefromid='', interp_order=0, loader=None, path_to_search='./data/dense_vnet_TC_craneal/', pixdim=(), spatial_window_size=(512, 512, 40))}
#
#
# Params al crear graph:
# App:  <niftynet.application.segmentation_application.SegmentationApplication object at 0x7ff3dbd4e710>
# Num_GPUs:  1
# Num_hilos:  1
# Is training?:  False
#
# 2019-06-18 18:36:24.847206: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-06-18 18:36:26.256774: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1411] Found device 0 with properties:
# name: TITAN Xp major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:05:00.0
# totalMemory: 11.91GiB freeMemory: 11.74GiB
# 2019-06-18 18:36:26.433643: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1411] Found device 1 with properties:
# name: TITAN Xp major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:06:00.0
# totalMemory: 11.91GiB freeMemory: 11.75GiB
# 2019-06-18 18:36:26.570228: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1411] Found device 2 with properties:
# name: TITAN Xp major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:09:00.0
# totalMemory: 11.91GiB freeMemory: 11.75GiB
# 2019-06-18 18:36:26.574288: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1490] Adding visible gpu devices: 0, 1, 2
# 2019-06-18 18:36:27.349325: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-06-18 18:36:27.349374: I tensorflow/core/common_runtime/gpu/gpu_device.cc:977]      0 1 2
# 2019-06-18 18:36:27.349381: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 0:   N Y Y
# 2019-06-18 18:36:27.349386: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 1:   Y N Y
# 2019-06-18 18:36:27.349391: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 2:   Y Y N
# 2019-06-18 18:36:27.350181: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/device:GPU:0 with 11361 MB memory) -> physical GPU (device: 0, name: TITAN Xp, pci bus id: 0000:05:00.0, compute capability: 6.1)
# 2019-06-18 18:36:27.502974: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/device:GPU:1 with 11363 MB memory) -> physical GPU (device: 1, name: TITAN Xp, pci bus id: 0000:06:00.0, compute capability: 6.1)
# 2019-06-18 18:36:27.655297: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/device:GPU:2 with 11363 MB memory) -> physical GPU (device: 2, name: TITAN Xp, pci bus id: 0000:09:00.0, compute capability: 6.1)
# INFO:niftynet: reading size of preprocessed images
# INFO:niftynet: initialised resize sampler {'image': (1, 512, 512, 40, 1, 1), 'image_location': (1, 7)}
# WARNING:niftynet: From /home/bsc0001/niftynet/lib/python3.6/site-packages/niftynet/engine/application_initializer.py:106: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with distribution=normal is deprecated and will be removed in a future version.
# Instructions for updating:
# `normal` is a deprecated alias for `truncated_normal`
#
# Should be:
#  <tensorflow.python.ops.init_ops.VarianceScaling object at 0x7ff3dbd347f0>
#
#
# W_INIT:
#  <tensorflow.python.ops.init_ops.VarianceScaling object at 0x7ff3dbd4eda0>
#
#
# Usando my Red
#
# INFO:niftynet: Import [MyNet] from /home/bsc0001/niftynet/extensions/dense_vnet_TC_craneal/CNN_TC_craneal_ictus.py.
#
# Should be:
#  <tensorflow.python.ops.init_ops.VarianceScaling object at 0x7ff3dbd4efd0>
#
# INFO:niftynet: using MyNet
# 2019-06-18 18:36:27.931767: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1490] Adding visible gpu devices: 0, 1, 2
# 2019-06-18 18:36:27.932012: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-06-18 18:36:27.932036: I tensorflow/core/common_runtime/gpu/gpu_device.cc:977]      0 1 2
# 2019-06-18 18:36:27.932050: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 0:   N Y Y
# 2019-06-18 18:36:27.932063: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 1:   Y N Y
# 2019-06-18 18:36:27.932076: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 2:   Y Y N
# 2019-06-18 18:36:27.932656: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/device:GPU:0 with 11361 MB memory) -> physical GPU (device: 0, name: TITAN Xp, pci bus id: 0000:05:00.0, compute capability: 6.1)
# 2019-06-18 18:36:27.933001: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/device:GPU:1 with 11363 MB memory) -> physical GPU (device: 1, name: TITAN Xp, pci bus id: 0000:06:00.0, compute capability: 6.1)
# 2019-06-18 18:36:27.933256: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/device:GPU:2 with 11363 MB memory) -> physical GPU (device: 2, name: TITAN Xp, pci bus id: 0000:09:00.0, compute capability: 6.1)
# INFO:niftynet: Initialising Dataset from 2 subjects...
# 2019-06-18 18:36:28.208063: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1490] Adding visible gpu devices: 0, 1, 2
# 2019-06-18 18:36:28.208212: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-06-18 18:36:28.208224: I tensorflow/core/common_runtime/gpu/gpu_device.cc:977]      0 1 2
# 2019-06-18 18:36:28.208231: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 0:   N Y Y
# 2019-06-18 18:36:28.208237: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 1:   Y N Y
# 2019-06-18 18:36:28.208242: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 2:   Y Y N
# 2019-06-18 18:36:28.208562: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 11361 MB memory) -> physical GPU (device: 0, name: TITAN Xp, pci bus id: 0000:05:00.0, compute capability: 6.1)
# 2019-06-18 18:36:28.208795: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 11363 MB memory) -> physical GPU (device: 1, name: TITAN Xp, pci bus id: 0000:06:00.0, compute capability: 6.1)
# 2019-06-18 18:36:28.208943: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:2 with 11363 MB memory) -> physical GPU (device: 2, name: TITAN Xp, pci bus id: 0000:09:00.0, compute capability: 6.1)
# INFO:niftynet: Restoring parameters from /home/bsc0001/niftynet/models/dense_vnet_TC_craneal/models/model.ckpt-30
# INFO:niftynet: inference iter 0,  (2.177435s)
# Saved /home/bsc0001/niftynet/models/dense_vnet_TC_craneal/segmentation_output/000__niftynet_out.nii.gz
# Saved /home/bsc0001/niftynet/models/dense_vnet_TC_craneal/segmentation_output/000b__niftynet_out.nii.gz
# INFO:niftynet: cleaning up...
# INFO:niftynet: stopping sampling threads
# INFO:niftynet: SegmentationApplication stopped (time in second 3.21).

# %%
! ls /home/bsc0001/niftynet/models/dense_vnet_TC_craneal/segmentation_output
# Out:
# 000b__niftynet_out.nii.gz  000__niftynet_out.nii.gz  inferred.csv
