# %%
# %cd /home/bsc0001/niftynet
# Out:
# /home/bsc0001/niftynet

# %%
# !pip install SimpleITK
# !pip install pyyaml

# %%
! net_segment train -c /home/bsc0001/niftynet/extensions/dense_vnet_TC_craneal/config.ini
# Out:
# CRITICAL:tensorflow:Optional Python module cv2 not found, please install cv2 and retry if the application fails.
# CRITICAL:tensorflow:Optional Python module skimage.io not found, please install skimage.io and retry if the application fails.
# NiftyNet version 0.5.0
# [CUSTOM]
# -- num_classes: 2
# -- output_prob: False
# -- label_normalisation: False
# -- softmax: True
# -- min_sampling_ratio: 0
# -- compulsory_labels: (0, 1)
# -- rand_samples: 0
# -- min_numb_labels: 1
# -- proba_connect: True
# -- evaluation_units: foreground
# -- inferred: ()
# -- label: ('label',)
# -- image: ('ct',)
# -- weight: ()
# -- sampler: ()
# -- name: net_segment
# [CONFIG_FILE]
# -- path: /home/bsc0001/niftynet/extensions/dense_vnet_TC_craneal/config.ini
# [CT]
# -- csv_file:
# -- path_to_search: ./data/dense_vnet_TC_craneal/
# -- filename_contains: ('TC',)
# -- filename_not_contains: ()
# -- filename_removefromid:
# -- interp_order: 1
# -- loader: None
# -- pixdim: ()
# -- axcodes: ('A', 'R', 'S')
# -- spatial_window_size: (512, 512, 40)
# [LABEL]
# -- csv_file:
# -- path_to_search: ./data/dense_vnet_TC_craneal/
# -- filename_contains: ('mask',)
# -- filename_not_contains: ()
# -- filename_removefromid:
# -- interp_order: 0
# -- loader: None
# -- pixdim: ()
# -- axcodes: ('A', 'R', 'S')
# -- spatial_window_size: (512, 512, 40)
# [SYSTEM]
# -- cuda_devices: ""
# -- num_threads: 3
# -- num_gpus: 3
# -- model_dir: /home/bsc0001/niftynet/models/dense_vnet_TC_craneal
# -- dataset_split_file: ./dataset_split.csv
# -- event_handler: ('model_saver', 'model_restorer', 'sampler_threading', 'apply_gradients', 'output_interpreter', 'console_logger', 'tensorboard_logger')
# -- iteration_generator: iteration_generator
# -- batch_size: 2
# -- queue_length: 12
# -- action: training
# [NETWORK]
# -- name: dense_vnet
# -- activation_function: relu
# -- batch_size: 2
# -- smaller_final_batch_mode: pad
# -- decay: 0.0
# -- reg_type: L2
# -- volume_padding_size: (0, 0, 0)
# -- volume_padding_mode: minimum
# -- window_sampling: resize
# -- queue_length: 12
# -- multimod_foreground_type: and
# -- histogram_ref_file: ./histogram_ref_file.txt
# -- norm_type: percentile
# -- cutoff: (0.01, 0.99)
# -- foreground_type: otsu_plus
# -- normalisation: False
# -- whitening: False
# -- normalise_foreground_only: False
# -- weight_initializer: he_normal
# -- bias_initializer: zeros
# -- keep_prob: 1.0
# -- weight_initializer_args: {}
# -- bias_initializer_args: {}
# [TRAINING]
# -- optimiser: adam
# -- sample_per_volume: 1
# -- rotation_angle: ()
# -- rotation_angle_x: ()
# -- rotation_angle_y: ()
# -- rotation_angle_z: ()
# -- scaling_percentage: ()
# -- antialiasing: True
# -- bias_field_range: ()
# -- bf_order: 3
# -- random_flipping_axes: -1
# -- do_elastic_deformation: False
# -- num_ctrl_points: 4
# -- deformation_sigma: 15
# -- proportion_to_deform: 0.5
# -- lr: 0.001
# -- loss_type: dense_vnet_TC_craneal.dice_hinge.dice
# -- starting_iter: 0
# -- save_every_n: 10
# -- tensorboard_every_n: 20
# -- max_iter: 30
# -- max_checkpoints: 100
# -- validation_every_n: -1
# -- validation_max_iter: 1
# -- exclude_fraction_for_validation: 0.0
# -- exclude_fraction_for_inference: 0.0
# -- vars_to_restore:
# -- vars_to_freeze:
# [INFERENCE]
# -- spatial_window_size: (512, 512, 40)
# -- inference_iter: 30
# -- dataset_to_infer:
# -- save_seg_dir: ./segmentation_output/
# -- output_postfix: _niftynet_out
# -- output_interp_order: 0
# -- border: (0, 0, 0)
# INFO:niftynet: starting segmentation application
# INFO:niftynet: `csv_file = ` not found, writing to "/home/bsc0001/niftynet/models/dense_vnet_TC_craneal/ct.csv" instead.
# INFO:niftynet: Overwriting existing: "/home/bsc0001/niftynet/models/dense_vnet_TC_craneal/ct.csv".
# INFO:niftynet: [ct] search file folders, writing csv file /home/bsc0001/niftynet/models/dense_vnet_TC_craneal/ct.csv
# INFO:niftynet: `csv_file = ` not found, writing to "/home/bsc0001/niftynet/models/dense_vnet_TC_craneal/label.csv" instead.
# INFO:niftynet: Overwriting existing: "/home/bsc0001/niftynet/models/dense_vnet_TC_craneal/label.csv".
# INFO:niftynet: [label] search file folders, writing csv file /home/bsc0001/niftynet/models/dense_vnet_TC_craneal/label.csv
# INFO:niftynet:
#
# Number of subjects 2, input section names: ['subject_id', 'ct', 'label']
# -- using all subjects (without data partitioning).
#
# INFO:niftynet: Image reader: loading 2 subjects from sections ('ct',) as input [image]
# INFO:niftynet: Image reader: loading 2 subjects from sections ('label',) as input [label]
#
# system_param:  {'SYSTEM': Namespace(action='training', batch_size='2', cuda_devices='""', dataset_split_file='/home/bsc0001/niftynet/models/dense_vnet_TC_craneal/dataset_split.csv', event_handler=('model_saver', 'model_restorer', 'sampler_threading', 'apply_gradients', 'output_interpreter', 'console_logger', 'tensorboard_logger'), iteration_generator='iteration_generator', model_dir='/home/bsc0001/niftynet/models/dense_vnet_TC_craneal', num_gpus=3, num_threads=3, queue_length='12'), 'NETWORK': Namespace(activation_function='relu', batch_size=2, bias_initializer='zeros', bias_initializer_args={}, cutoff=(0.01, 0.99), decay=0.0, foreground_type='otsu_plus', histogram_ref_file='/home/bsc0001/niftynet/models/dense_vnet_TC_craneal/histogram_ref_file.txt', keep_prob=1.0, multimod_foreground_type='and', name='dense_vnet', norm_type='percentile', normalisation=False, normalise_foreground_only=False, queue_length=12, reg_type='L2', smaller_final_batch_mode='pad', volume_padding_mode='minimum', volume_padding_size=(0, 0, 0), weight_initializer='he_normal', weight_initializer_args={}, whitening=False, window_sampling='resize'), 'TRAINING': Namespace(antialiasing=True, bf_order=3, bias_field_range=(), deformation_sigma=15, do_elastic_deformation=False, exclude_fraction_for_inference=0.0, exclude_fraction_for_validation=0.0, loss_type='dense_vnet_TC_craneal.dice_hinge.dice', lr=0.001, max_checkpoints=100, max_iter=30, num_ctrl_points=4, optimiser='adam', proportion_to_deform=0.5, random_flipping_axes=-1, rotation_angle=(), rotation_angle_x=(), rotation_angle_y=(), rotation_angle_z=(), sample_per_volume=1, save_every_n=10, scaling_percentage=(), starting_iter=0, tensorboard_every_n=20, validation_every_n=-1, validation_max_iter=1, vars_to_freeze='', vars_to_restore=''), 'INFERENCE': Namespace(border=(0, 0, 0), dataset_to_infer='', inference_iter=30, output_interp_order=0, output_postfix='_niftynet_out', save_seg_dir='/home/bsc0001/niftynet/models/dense_vnet_TC_craneal/segmentation_output', spatial_window_size=(512, 512, 40)), 'CUSTOM': Namespace(compulsory_labels=(0, 1), evaluation_units='foreground', image=('ct',), inferred=(), label=('label',), label_normalisation=False, min_numb_labels=1, min_sampling_ratio=0, name='net_segment', num_classes=2, output_prob=False, proba_connect=True, rand_samples=0, sampler=(), softmax=True, weight=()), 'CONFIG_FILE': Namespace(path='/home/bsc0001/niftynet/extensions/dense_vnet_TC_craneal/config.ini')}
#
# input_data_param: {'ct': Namespace(axcodes=('A', 'R', 'S'), csv_file='', filename_contains=('TC',), filename_not_contains=(), filename_removefromid='', interp_order=1, loader=None, path_to_search='./data/dense_vnet_TC_craneal/', pixdim=(), spatial_window_size=(512, 512, 40)), 'label': Namespace(axcodes=('A', 'R', 'S'), csv_file='', filename_contains=('mask',), filename_not_contains=(), filename_removefromid='', interp_order=0, loader=None, path_to_search='./data/dense_vnet_TC_craneal/', pixdim=(), spatial_window_size=(512, 512, 40))}
#
#
# Params al crear graph:
# App:  <niftynet.application.segmentation_application.SegmentationApplication object at 0x7f7f39fd8828>
# Num_GPUs:  3
# Num_hilos:  3
# Is training?:  True
#
# 2019-06-18 19:06:53.314472: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-06-18 19:06:54.669156: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1411] Found device 0 with properties:
# name: TITAN Xp major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:05:00.0
# totalMemory: 11.91GiB freeMemory: 11.74GiB
# 2019-06-18 19:06:54.832838: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1411] Found device 1 with properties:
# name: TITAN Xp major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:06:00.0
# totalMemory: 11.91GiB freeMemory: 11.75GiB
# 2019-06-18 19:06:54.981581: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1411] Found device 2 with properties:
# name: TITAN Xp major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:09:00.0
# totalMemory: 11.91GiB freeMemory: 11.75GiB
# 2019-06-18 19:06:54.985398: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1490] Adding visible gpu devices: 0, 1, 2
# 2019-06-18 19:06:55.784072: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-06-18 19:06:55.784107: I tensorflow/core/common_runtime/gpu/gpu_device.cc:977]      0 1 2
# 2019-06-18 19:06:55.784113: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 0:   N Y Y
# 2019-06-18 19:06:55.784118: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 1:   Y N Y
# 2019-06-18 19:06:55.784122: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 2:   Y Y N
# 2019-06-18 19:06:55.784825: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/device:GPU:0 with 11361 MB memory) -> physical GPU (device: 0, name: TITAN Xp, pci bus id: 0000:05:00.0, compute capability: 6.1)
# 2019-06-18 19:06:55.942754: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/device:GPU:1 with 11363 MB memory) -> physical GPU (device: 1, name: TITAN Xp, pci bus id: 0000:06:00.0, compute capability: 6.1)
# 2019-06-18 19:06:56.097473: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/device:GPU:2 with 11363 MB memory) -> physical GPU (device: 2, name: TITAN Xp, pci bus id: 0000:09:00.0, compute capability: 6.1)
# INFO:niftynet: reading size of preprocessed images
# INFO:niftynet: initialised resize sampler {'image': (1, 512, 512, 40, 1, 1), 'image_location': (1, 7), 'label': (1, 512, 512, 40, 1, 1), 'label_location': (1, 7)}
# WARNING:niftynet: From /home/bsc0001/niftynet/lib/python3.6/site-packages/niftynet/engine/application_initializer.py:106: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with distribution=normal is deprecated and will be removed in a future version.
# Instructions for updating:
# `normal` is a deprecated alias for `truncated_normal`
#
# Should be:
#  <tensorflow.python.ops.init_ops.VarianceScaling object at 0x7f7f39fbe978>
#
#
# W_INIT:
#  <tensorflow.python.ops.init_ops.VarianceScaling object at 0x7f7f39fd8dd8>
#
#
# Should be:
#  <tensorflow.python.ops.init_ops.VarianceScaling object at 0x7f7f39fd8dd8>
#
# INFO:niftynet: using DenseVNet
# 2019-06-18 19:06:56.321564: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1490] Adding visible gpu devices: 0, 1, 2
# 2019-06-18 19:06:56.321703: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-06-18 19:06:56.321714: I tensorflow/core/common_runtime/gpu/gpu_device.cc:977]      0 1 2
# 2019-06-18 19:06:56.321721: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 0:   N Y Y
# 2019-06-18 19:06:56.321727: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 1:   Y N Y
# 2019-06-18 19:06:56.321733: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 2:   Y Y N
# 2019-06-18 19:06:56.322035: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/device:GPU:0 with 11361 MB memory) -> physical GPU (device: 0, name: TITAN Xp, pci bus id: 0000:05:00.0, compute capability: 6.1)
# 2019-06-18 19:06:56.322331: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/device:GPU:1 with 11363 MB memory) -> physical GPU (device: 1, name: TITAN Xp, pci bus id: 0000:06:00.0, compute capability: 6.1)
# 2019-06-18 19:06:56.322488: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/device:GPU:2 with 11363 MB memory) -> physical GPU (device: 2, name: TITAN Xp, pci bus id: 0000:09:00.0, compute capability: 6.1)
# INFO:niftynet: Initialising Dataset from 2 subjects...
# INFO:niftynet: Import [dice] from /home/bsc0001/niftynet/extensions/dense_vnet_TC_craneal/dice_hinge.py.
# 2019-06-18 19:07:06.306230: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1490] Adding visible gpu devices: 0, 1, 2
# 2019-06-18 19:07:06.306384: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-06-18 19:07:06.306396: I tensorflow/core/common_runtime/gpu/gpu_device.cc:977]      0 1 2
# 2019-06-18 19:07:06.306403: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 0:   N Y Y
# 2019-06-18 19:07:06.306409: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 1:   Y N Y
# 2019-06-18 19:07:06.306415: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 2:   Y Y N
# 2019-06-18 19:07:06.306725: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/device:GPU:0 with 11361 MB memory) -> physical GPU (device: 0, name: TITAN Xp, pci bus id: 0000:05:00.0, compute capability: 6.1)
# 2019-06-18 19:07:06.306952: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/device:GPU:1 with 11363 MB memory) -> physical GPU (device: 1, name: TITAN Xp, pci bus id: 0000:06:00.0, compute capability: 6.1)
# 2019-06-18 19:07:06.307108: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/device:GPU:2 with 11363 MB memory) -> physical GPU (device: 2, name: TITAN Xp, pci bus id: 0000:09:00.0, compute capability: 6.1)
# INFO:niftynet: Import [dice] from /home/bsc0001/niftynet/extensions/dense_vnet_TC_craneal/dice_hinge.py.
# 2019-06-18 19:07:14.888234: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1490] Adding visible gpu devices: 0, 1, 2
# 2019-06-18 19:07:14.888380: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-06-18 19:07:14.888392: I tensorflow/core/common_runtime/gpu/gpu_device.cc:977]      0 1 2
# 2019-06-18 19:07:14.888399: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 0:   N Y Y
# 2019-06-18 19:07:14.888405: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 1:   Y N Y
# 2019-06-18 19:07:14.888411: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 2:   Y Y N
# 2019-06-18 19:07:14.888721: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/device:GPU:0 with 11361 MB memory) -> physical GPU (device: 0, name: TITAN Xp, pci bus id: 0000:05:00.0, compute capability: 6.1)
# 2019-06-18 19:07:14.888941: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/device:GPU:1 with 11363 MB memory) -> physical GPU (device: 1, name: TITAN Xp, pci bus id: 0000:06:00.0, compute capability: 6.1)
# 2019-06-18 19:07:14.889081: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/device:GPU:2 with 11363 MB memory) -> physical GPU (device: 2, name: TITAN Xp, pci bus id: 0000:09:00.0, compute capability: 6.1)
# INFO:niftynet: Import [dice] from /home/bsc0001/niftynet/extensions/dense_vnet_TC_craneal/dice_hinge.py.
# 2019-06-18 19:08:00.252164: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1490] Adding visible gpu devices: 0, 1, 2
# 2019-06-18 19:08:00.252418: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-06-18 19:08:00.252438: I tensorflow/core/common_runtime/gpu/gpu_device.cc:977]      0 1 2
# 2019-06-18 19:08:00.252452: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 0:   N Y Y
# 2019-06-18 19:08:00.252463: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 1:   Y N Y
# 2019-06-18 19:08:00.252475: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 2:   Y Y N
# 2019-06-18 19:08:00.253037: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 11361 MB memory) -> physical GPU (device: 0, name: TITAN Xp, pci bus id: 0000:05:00.0, compute capability: 6.1)
# 2019-06-18 19:08:00.253325: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 11363 MB memory) -> physical GPU (device: 1, name: TITAN Xp, pci bus id: 0000:06:00.0, compute capability: 6.1)
# 2019-06-18 19:08:00.253603: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:2 with 11363 MB memory) -> physical GPU (device: 2, name: TITAN Xp, pci bus id: 0000:09:00.0, compute capability: 6.1)
# INFO:niftynet: Parameters from random initialisations ...
# 2019-06-18 19:08:53.948245: I tensorflow/core/kernels/cuda_solvers.cc:159] Creating CudaSolver handles for stream 0x5647a8799780
# 2019-06-18 19:08:57.398006: I tensorflow/core/kernels/cuda_solvers.cc:159] Creating CudaSolver handles for stream 0x5647a87a7b10
# 2019-06-18 19:08:57.952768: I tensorflow/core/kernels/cuda_solvers.cc:159] Creating CudaSolver handles for stream 0x5647862bdd80
# dice[0.76224184 0]
# dice[0.76506 0]
# dice[0.770475507 0.067246072]
# dice[0.768746734 0.0662300736]
# dice[0.76704 0.0663597658]
# dice[0.765336 0]
# INFO:niftynet: training iter 1, loss=5.867440700531006, loss_1=5.883301258087158, loss_2=5.885797500610352 (84.976825s)
# dice[0.792771 0]
# dice[0.795704484 0]
# dice[0.811346769 0.122271284]
# dice[0.815015 0.124167599]
# dice[0.797393143 0]
# dice[0.812066555 0.122772396]
# INFO:niftynet: training iter 2, loss=5.56736421585083, loss_1=5.567246913909912, loss_2=5.567011833190918 (14.688643s)
# dice[0.888797104 0]
# dice[0.885813177 0.157047331]
# dice[0.883930326 0.157674089]
# dice[0.874366403 0.153623149]
# dice[0.880827725 0.155926093]
# dice[0.882961512 0.156363979]
# INFO:niftynet: training iter 3, loss=0.4797675311565399, loss_1=0.4800964295864105, loss_2=5.520802974700928 (16.138036s)
# dice[0.923016131 0]
# dice[0.931524098 0]
# dice[0.914762795 0.181086898]
# dice[0.923205435 0]
# dice[0.932833731 0]
# dice[0.915503263 0.186688811]
# INFO:niftynet: training iter 4, loss=5.491570949554443, loss_1=10.538444519042969, loss_2=5.492828845977783 (15.043481s)
# dice[0.95429343 0]
# dice[0.946907938 0.20608376]
# dice[0.948580503 0.196060792]
# dice[0.947250068 0.203345299]
# dice[0.953773856 0]
# dice[0.951016068 0.211438328]
# INFO:niftynet: training iter 5, loss=0.42322608828544617, loss_1=5.473308563232422, loss_2=5.473778247833252 (15.982454s)
# dice[0.95427233 0]
# dice[0.956844866 0]
# dice[0.958992422 0]
# dice[0.957428575 0]
# dice[0.956935942 0]
# dice[0.954774261 0.246472105]
# INFO:niftynet: training iter 6, loss=10.521018028259277, loss_1=10.522074699401855, loss_2=5.460477352142334 (17.381717s)
# dice[0.962073386 0]
# dice[0.962189853 0.268636]
# dice[0.963513553 0.273279846]
# dice[0.964690864 0]
# dice[0.964011133 0]
# dice[0.964871824 0]
# INFO:niftynet: training iter 7, loss=5.451290607452393, loss_1=5.449583530426025, loss_2=10.518308639526367 (19.342896s)
# dice[0.966255724 0]
# dice[0.967615843 0]
# dice[0.96754837 0]
# dice[0.965830445 0]
# dice[0.963968515 0.259702355]
# dice[0.964100599 0.264007539]
# INFO:niftynet: training iter 8, loss=5.451086044311523, loss_1=5.452518463134766, loss_2=10.516637802124023 (15.037527s)
# dice[0.967651546 0]
# dice[0.967718542 0.315406501]
# dice[0.969398916 0.318726391]
# dice[0.967921674 0]
# dice[0.967309296 0.294930637]
# dice[0.968957961 0.308972508]
# INFO:niftynet: training iter 9, loss=0.3584860563278198, loss_1=10.516106605529785, loss_2=0.36365875601768494 (16.371317s)
# dice[0.965545356 0]
# dice[0.968982 0]
# dice[0.967556238 0.314778835]
# dice[0.968244791 0.32443]
# dice[0.966106951 0.312413126]
# dice[0.967422187 0.306736797]
# INFO:niftynet: training iter 10, loss=0.36087650060653687, loss_1=5.438124179840088, loss_2=5.4354448318481445 (16.121187s)
# INFO:niftynet: iter 10 saved: /home/bsc0001/niftynet/models/dense_vnet_TC_craneal/models/model.ckpt
# dice[0.966854393 0]
# dice[0.963904738 0]
# dice[0.969344318 0.347167969]
# dice[0.963180661 0]
# dice[0.967940271 0.330228984]
# dice[0.9672544 0.328825533]
# INFO:niftynet: training iter 11, loss=10.518228530883789, loss_1=0.3468519449234009, loss_2=5.433743953704834 (16.964468s)
# dice[0.967555165 0]
# dice[0.96940738 0.353416502]
# dice[0.970821202 0.351024866]
# dice[0.967786193 0]
# dice[0.968824 0]
# dice[0.968868077 0]
# INFO:niftynet: training iter 12, loss=10.516164779663086, loss_1=5.427332401275635, loss_2=5.427076816558838 (17.120594s)
# dice[0.972022951 0]
# dice[0.972831726 0.30754903]
# dice[0.972032726 0.291907161]
# dice[0.970602274 0]
# dice[0.974476278 0.324516237]
# dice[0.970908761 0.291270167]
# INFO:niftynet: training iter 13, loss=10.51434326171875, loss_1=0.35515668988227844, loss_2=0.36847031116485596 (17.559134s)
# dice[0.958759785 0]
# dice[0.961307704 0.324107766]
# dice[0.962970376 0.331262827]
# dice[0.956844687 0]
# dice[0.961543 0]
# dice[0.964329481 0.335694075]
# INFO:niftynet: training iter 14, loss=0.3514358103275299, loss_1=10.521099090576172, loss_2=5.438260078430176 (16.104856s)
# dice[0.960976481 0.312340468]
# dice[0.958689749 0.305192769]
# dice[0.957099795 0.311089]
# dice[0.958417892 0]
# dice[0.958829701 0.302682787]
# dice[0.961536586 0.318907112]
# INFO:niftynet: training iter 15, loss=0.3639184534549713, loss_1=5.443348407745361, loss_2=0.3662926256656647 (16.092735s)
# dice[0.957661927 0]
# dice[0.961020827 0]
# dice[0.96176964 0.317043304]
# dice[0.95738405 0]
# dice[0.959897518 0.312212]
# dice[0.963526905 0.325184077]
# INFO:niftynet: training iter 16, loss=5.441717147827148, loss_1=0.35811904072761536, loss_2=10.521238327026367 (19.153466s)
# dice[0.96573633 0]
# dice[0.964196682 0]
# dice[0.966821253 0.31994465]
# dice[0.965153396 0]
# dice[0.964675248 0.322715908]
# dice[0.965276718 0.308135331]
# INFO:niftynet: training iter 17, loss=0.3599555194377899, loss_1=10.517662048339844, loss_2=5.436717987060547 (16.245288s)
# dice[0.968696058 0]
# dice[0.970003724 0]
# dice[0.969007 0]
# dice[0.969046772 0]
# dice[0.967604756 0]
# dice[0.969322205 0.322009146]
# INFO:niftynet: training iter 18, loss=10.515846252441406, loss_1=5.434665679931641, loss_2=10.51556396484375 (18.072721s)
# dice[0.972948194 0]
# dice[0.972564459 0]
# dice[0.973487139 0]
# dice[0.972553492 0]
# dice[0.972650826 0]
# dice[0.974037 0.320428342]
# INFO:niftynet: training iter 19, loss=10.513465881347656, loss_1=5.433242321014404, loss_2=10.51362419128418 (17.918342s)
# dice[0.976326346 0]
# dice[0.974298835 0.274218798]
# dice[0.97252059 0.253672481]
# dice[0.974910736 0]
# dice[0.975264072 0.250593752]
# dice[0.975269318 0.272762239]
# INFO:niftynet: training iter 20, loss=10.512190818786621, loss_1=0.3814438283443451, loss_2=0.38140612840652466 (68.365311s)
# INFO:niftynet: iter 20 saved: /home/bsc0001/niftynet/models/dense_vnet_TC_craneal/models/model.ckpt
# dice[0.974324048 0.328653395]
# dice[0.976121843 0.332953215]
# dice[0.974545836 0.304903328]
# dice[0.974253237 0]
# dice[0.97521019 0]
# dice[0.975511312 0.310610086]
# INFO:niftynet: training iter 21, loss=0.35860735177993774, loss_1=5.430692672729492, loss_2=5.428928852081299 (16.057719s)
# dice[0.974907279 0]
# dice[0.975564 0]
# dice[0.971315205 0.313066453]
# dice[0.974898934 0.349311262]
# dice[0.97359246 0.357298315]
# dice[0.974623799 0.328300089]
# INFO:niftynet: training iter 22, loss=0.3531736135482788, loss_1=5.423386573791504, loss_2=5.425220489501953 (16.097733s)
# dice[0.973326206 0]
# dice[0.970608473 0]
# dice[0.97052145 0]
# dice[0.970688045 0.338653028]
# dice[0.97224164 0.351383537]
# dice[0.969893575 0.341364324]
# INFO:niftynet: training iter 23, loss=5.4264631271362305, loss_1=5.4295334815979, loss_2=5.429333209991455 (19.157157s)
# dice[0.96856904 0]
# dice[0.969837964 0.344831735]
# dice[0.971012473 0.34329617]
# dice[0.972936392 0.379314184]
# dice[0.968623936 0]
# dice[0.970953524 0]
# INFO:niftynet: training iter 24, loss=5.429176330566406, loss_1=5.428684711456299, loss_2=5.419795036315918 (19.275404s)
# dice[0.971121073 0]
# dice[0.972428143 0]
# dice[0.972533762 0.346712083]
# dice[0.973451793 0.381935775]
# dice[0.971578658 0.364074141]
# dice[0.975334 0.367074102]
# INFO:niftynet: training iter 25, loss=0.3345865309238434, loss_1=5.422979831695557, loss_2=5.418373107910156 (16.285145s)
# dice[0.971287191 0]
# dice[0.970179379 0]
# dice[0.968082547 0]
# dice[0.96905762 0]
# dice[0.971285939 0]
# dice[0.972162247 0.357424051]
# INFO:niftynet: training iter 26, loss=10.515157699584961, loss_1=10.515190124511719, loss_2=5.424781799316406 (17.853462s)
# dice[0.972741604 0]
# dice[0.974529624 0]
# dice[0.978534877 0.369540572]
# dice[0.972470403 0]
# dice[0.974066 0.350440681]
# dice[0.978823125 0.367234319]
# INFO:niftynet: training iter 27, loss=5.425240993499756, loss_1=0.32646679878234863, loss_2=10.513696670532227 (19.335975s)
# dice[0.97191608 0]
# dice[0.976019442 0.371798337]
# dice[0.979205132 0.390689164]
# dice[0.973725498 0]
# dice[0.97501862 0]
# dice[0.977950811 0.374954432]
# INFO:niftynet: training iter 28, loss=10.513589859008789, loss_1=0.31930011510849, loss_2=5.419291019439697 (17.310529s)
# dice[0.971525669 0]
# dice[0.978328228 0.392327458]
# dice[0.975433886 0.360354334]
# dice[0.971719742 0]
# dice[0.978245556 0.392949224]
# dice[0.97831136 0.391552925]
# INFO:niftynet: training iter 29, loss=0.3235868811607361, loss_1=0.31453737616539, loss_2=10.514188766479492 (16.208956s)
# dice[0.972630322 0]
# dice[0.96847856 0]
# dice[0.972420871 0]
# dice[0.97145623 0]
# dice[0.977437854 0.388860792]
# dice[0.977229714 0.402962655]
# INFO:niftynet: training iter 30, loss=10.515016555786133, loss_1=5.4152679443359375, loss_2=5.411847114562988 (17.998333s)
# INFO:niftynet: iter 30 saved: /home/bsc0001/niftynet/models/dense_vnet_TC_craneal/models/model.ckpt
# INFO:niftynet: cleaning up...
# INFO:niftynet: iter 30 saved: /home/bsc0001/niftynet/models/dense_vnet_TC_craneal/models/model.ckpt
# INFO:niftynet: stopping sampling threads
# INFO:niftynet: SegmentationApplication stopped (time in second 672.17).

# %%
# !ls /home/bsc0001/niftynet/models/dense_vnet_TC_craneal/models
# Out:
# checkpoint			   model.ckpt-20.data-00000-of-00001
# model.ckpt-10.data-00000-of-00001  model.ckpt-20.index
# model.ckpt-10.index		   model.ckpt-20.meta
# model.ckpt-10.meta		   model.ckpt-30.data-00000-of-00001
# model.ckpt-1.data-00000-of-00001   model.ckpt-30.index
# model.ckpt-1.index		   model.ckpt-30.meta
# model.ckpt-1.meta

# %%
# Segmentar utilizando los datos del entrenamiento, desde la configuración inicial.
! net_segment inference -c ~/niftynet/extensions/dense_vnet_TC_craneal/config.ini
# Out:
# CRITICAL:tensorflow:Optional Python module cv2 not found, please install cv2 and retry if the application fails.
# CRITICAL:tensorflow:Optional Python module skimage.io not found, please install skimage.io and retry if the application fails.
# NiftyNet version 0.5.0
# [CUSTOM]
# -- num_classes: 2
# -- output_prob: False
# -- label_normalisation: False
# -- softmax: True
# -- min_sampling_ratio: 0
# -- compulsory_labels: (0, 1)
# -- rand_samples: 0
# -- min_numb_labels: 1
# -- proba_connect: True
# -- evaluation_units: foreground
# -- image: ('ct',)
# -- sampler: ()
# -- weight: ()
# -- inferred: ()
# -- label: ('label',)
# -- name: net_segment
# [CONFIG_FILE]
# -- path: /home/bsc0001/niftynet/extensions/dense_vnet_TC_craneal/config.ini
# [CT]
# -- csv_file:
# -- path_to_search: ./data/dense_vnet_TC_craneal/
# -- filename_contains: ('TC',)
# -- filename_not_contains: ()
# -- filename_removefromid:
# -- interp_order: 1
# -- loader: None
# -- pixdim: ()
# -- axcodes: ('A', 'R', 'S')
# -- spatial_window_size: (512, 512, 40)
# [LABEL]
# -- csv_file:
# -- path_to_search: ./data/dense_vnet_TC_craneal/
# -- filename_contains: ('mask',)
# -- filename_not_contains: ()
# -- filename_removefromid:
# -- interp_order: 0
# -- loader: None
# -- pixdim: ()
# -- axcodes: ('A', 'R', 'S')
# -- spatial_window_size: (512, 512, 40)
# [SYSTEM]
# -- cuda_devices: ""
# -- num_threads: 3
# -- num_gpus: 3
# -- model_dir: /home/bsc0001/niftynet/models/dense_vnet_TC_craneal
# -- dataset_split_file: ./dataset_split.csv
# -- event_handler: ('model_saver', 'model_restorer', 'sampler_threading', 'apply_gradients', 'output_interpreter', 'console_logger', 'tensorboard_logger')
# -- iteration_generator: iteration_generator
# -- batch_size: 2
# -- queue_length: 12
# -- action: inference
# [NETWORK]
# -- name: dense_vnet
# -- activation_function: relu
# -- batch_size: 2
# -- smaller_final_batch_mode: pad
# -- decay: 0.0
# -- reg_type: L2
# -- volume_padding_size: (0, 0, 0)
# -- volume_padding_mode: minimum
# -- window_sampling: resize
# -- queue_length: 12
# -- multimod_foreground_type: and
# -- histogram_ref_file: ./histogram_ref_file.txt
# -- norm_type: percentile
# -- cutoff: (0.01, 0.99)
# -- foreground_type: otsu_plus
# -- normalisation: False
# -- whitening: False
# -- normalise_foreground_only: False
# -- weight_initializer: he_normal
# -- bias_initializer: zeros
# -- keep_prob: 1.0
# -- weight_initializer_args: {}
# -- bias_initializer_args: {}
# [TRAINING]
# -- optimiser: adam
# -- sample_per_volume: 1
# -- rotation_angle: ()
# -- rotation_angle_x: ()
# -- rotation_angle_y: ()
# -- rotation_angle_z: ()
# -- scaling_percentage: ()
# -- antialiasing: True
# -- bias_field_range: ()
# -- bf_order: 3
# -- random_flipping_axes: -1
# -- do_elastic_deformation: False
# -- num_ctrl_points: 4
# -- deformation_sigma: 15
# -- proportion_to_deform: 0.5
# -- lr: 0.001
# -- loss_type: dense_vnet_TC_craneal.dice_hinge.dice
# -- starting_iter: 0
# -- save_every_n: 10
# -- tensorboard_every_n: 20
# -- max_iter: 30
# -- max_checkpoints: 100
# -- validation_every_n: -1
# -- validation_max_iter: 1
# -- exclude_fraction_for_validation: 0.0
# -- exclude_fraction_for_inference: 0.0
# -- vars_to_restore:
# -- vars_to_freeze:
# [INFERENCE]
# -- spatial_window_size: (512, 512, 40)
# -- inference_iter: 30
# -- dataset_to_infer:
# -- save_seg_dir: ./segmentation_output/
# -- output_postfix: _niftynet_out
# -- output_interp_order: 0
# -- border: (0, 0, 0)
# INFO:niftynet: starting segmentation application
# INFO:niftynet: `csv_file = ` not found, writing to "/home/bsc0001/niftynet/models/dense_vnet_TC_craneal/ct.csv" instead.
# INFO:niftynet: Overwriting existing: "/home/bsc0001/niftynet/models/dense_vnet_TC_craneal/ct.csv".
# INFO:niftynet: [ct] search file folders, writing csv file /home/bsc0001/niftynet/models/dense_vnet_TC_craneal/ct.csv
# INFO:niftynet: `csv_file = ` not found, writing to "/home/bsc0001/niftynet/models/dense_vnet_TC_craneal/label.csv" instead.
# INFO:niftynet: Overwriting existing: "/home/bsc0001/niftynet/models/dense_vnet_TC_craneal/label.csv".
# INFO:niftynet: [label] search file folders, writing csv file /home/bsc0001/niftynet/models/dense_vnet_TC_craneal/label.csv
# INFO:niftynet:
#
# Number of subjects 2, input section names: ['subject_id', 'ct', 'label']
# -- using all subjects (without data partitioning).
#
# INFO:niftynet: Image reader: loading 2 subjects from sections ('ct',) as input [image]
#
# system_param:  {'SYSTEM': Namespace(action='inference', batch_size='2', cuda_devices='""', dataset_split_file='/home/bsc0001/niftynet/models/dense_vnet_TC_craneal/dataset_split.csv', event_handler=('model_saver', 'model_restorer', 'sampler_threading', 'apply_gradients', 'output_interpreter', 'console_logger', 'tensorboard_logger'), iteration_generator='iteration_generator', model_dir='/home/bsc0001/niftynet/models/dense_vnet_TC_craneal', num_gpus=3, num_threads=3, queue_length='12'), 'NETWORK': Namespace(activation_function='relu', batch_size=2, bias_initializer='zeros', bias_initializer_args={}, cutoff=(0.01, 0.99), decay=0.0, foreground_type='otsu_plus', histogram_ref_file='/home/bsc0001/niftynet/models/dense_vnet_TC_craneal/histogram_ref_file.txt', keep_prob=1.0, multimod_foreground_type='and', name='dense_vnet', norm_type='percentile', normalisation=False, normalise_foreground_only=False, queue_length=12, reg_type='L2', smaller_final_batch_mode='pad', volume_padding_mode='minimum', volume_padding_size=(0, 0, 0), weight_initializer='he_normal', weight_initializer_args={}, whitening=False, window_sampling='resize'), 'TRAINING': Namespace(antialiasing=True, bf_order=3, bias_field_range=(), deformation_sigma=15, do_elastic_deformation=False, exclude_fraction_for_inference=0.0, exclude_fraction_for_validation=0.0, loss_type='dense_vnet_TC_craneal.dice_hinge.dice', lr=0.001, max_checkpoints=100, max_iter=30, num_ctrl_points=4, optimiser='adam', proportion_to_deform=0.5, random_flipping_axes=-1, rotation_angle=(), rotation_angle_x=(), rotation_angle_y=(), rotation_angle_z=(), sample_per_volume=1, save_every_n=10, scaling_percentage=(), starting_iter=0, tensorboard_every_n=20, validation_every_n=-1, validation_max_iter=1, vars_to_freeze='', vars_to_restore=''), 'INFERENCE': Namespace(border=(0, 0, 0), dataset_to_infer='', inference_iter=30, output_interp_order=0, output_postfix='_niftynet_out', save_seg_dir='/home/bsc0001/niftynet/models/dense_vnet_TC_craneal/segmentation_output', spatial_window_size=(512, 512, 40)), 'CUSTOM': Namespace(compulsory_labels=(0, 1), evaluation_units='foreground', image=('ct',), inferred=(), label=('label',), label_normalisation=False, min_numb_labels=1, min_sampling_ratio=0, name='net_segment', num_classes=2, output_prob=False, proba_connect=True, rand_samples=0, sampler=(), softmax=True, weight=()), 'CONFIG_FILE': Namespace(path='/home/bsc0001/niftynet/extensions/dense_vnet_TC_craneal/config.ini')}
#
# input_data_param: {'ct': Namespace(axcodes=('A', 'R', 'S'), csv_file='', filename_contains=('TC',), filename_not_contains=(), filename_removefromid='', interp_order=1, loader=None, path_to_search='./data/dense_vnet_TC_craneal/', pixdim=(), spatial_window_size=(512, 512, 40)), 'label': Namespace(axcodes=('A', 'R', 'S'), csv_file='', filename_contains=('mask',), filename_not_contains=(), filename_removefromid='', interp_order=0, loader=None, path_to_search='./data/dense_vnet_TC_craneal/', pixdim=(), spatial_window_size=(512, 512, 40))}
#
#
# Params al crear graph:
# App:  <niftynet.application.segmentation_application.SegmentationApplication object at 0x7f5374a4b6a0>
# Num_GPUs:  1
# Num_hilos:  1
# Is training?:  False
#
# 2019-06-18 19:19:46.542131: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-06-18 19:19:47.904570: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1411] Found device 0 with properties:
# name: TITAN Xp major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:05:00.0
# totalMemory: 11.91GiB freeMemory: 11.74GiB
# 2019-06-18 19:19:48.085976: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1411] Found device 1 with properties:
# name: TITAN Xp major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:06:00.0
# totalMemory: 11.91GiB freeMemory: 11.75GiB
# 2019-06-18 19:19:48.228214: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1411] Found device 2 with properties:
# name: TITAN Xp major: 6 minor: 1 memoryClockRate(GHz): 1.582
# pciBusID: 0000:09:00.0
# totalMemory: 11.91GiB freeMemory: 11.75GiB
# 2019-06-18 19:19:48.231716: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1490] Adding visible gpu devices: 0, 1, 2
# 2019-06-18 19:19:49.026573: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-06-18 19:19:49.026624: I tensorflow/core/common_runtime/gpu/gpu_device.cc:977]      0 1 2
# 2019-06-18 19:19:49.026631: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 0:   N Y Y
# 2019-06-18 19:19:49.026636: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 1:   Y N Y
# 2019-06-18 19:19:49.026641: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 2:   Y Y N
# 2019-06-18 19:19:49.027341: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/device:GPU:0 with 11361 MB memory) -> physical GPU (device: 0, name: TITAN Xp, pci bus id: 0000:05:00.0, compute capability: 6.1)
# 2019-06-18 19:19:49.183365: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/device:GPU:1 with 11363 MB memory) -> physical GPU (device: 1, name: TITAN Xp, pci bus id: 0000:06:00.0, compute capability: 6.1)
# 2019-06-18 19:19:49.338978: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/device:GPU:2 with 11363 MB memory) -> physical GPU (device: 2, name: TITAN Xp, pci bus id: 0000:09:00.0, compute capability: 6.1)
# INFO:niftynet: reading size of preprocessed images
# INFO:niftynet: initialised resize sampler {'image': (1, 512, 512, 40, 1, 1), 'image_location': (1, 7)}
# WARNING:niftynet: From /home/bsc0001/niftynet/lib/python3.6/site-packages/niftynet/engine/application_initializer.py:106: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with distribution=normal is deprecated and will be removed in a future version.
# Instructions for updating:
# `normal` is a deprecated alias for `truncated_normal`
#
# Should be:
#  <tensorflow.python.ops.init_ops.VarianceScaling object at 0x7f5374a320b8>
#
#
# W_INIT:
#  <tensorflow.python.ops.init_ops.VarianceScaling object at 0x7f5374a4bf28>
#
#
# Should be:
#  <tensorflow.python.ops.init_ops.VarianceScaling object at 0x7f5374a4bf28>
#
# INFO:niftynet: using DenseVNet
# 2019-06-18 19:19:49.551726: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1490] Adding visible gpu devices: 0, 1, 2
# 2019-06-18 19:19:49.551869: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-06-18 19:19:49.551881: I tensorflow/core/common_runtime/gpu/gpu_device.cc:977]      0 1 2
# 2019-06-18 19:19:49.551887: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 0:   N Y Y
# 2019-06-18 19:19:49.551893: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 1:   Y N Y
# 2019-06-18 19:19:49.551899: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 2:   Y Y N
# 2019-06-18 19:19:49.552210: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/device:GPU:0 with 11361 MB memory) -> physical GPU (device: 0, name: TITAN Xp, pci bus id: 0000:05:00.0, compute capability: 6.1)
# 2019-06-18 19:19:49.552510: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/device:GPU:1 with 11363 MB memory) -> physical GPU (device: 1, name: TITAN Xp, pci bus id: 0000:06:00.0, compute capability: 6.1)
# 2019-06-18 19:19:49.552687: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/device:GPU:2 with 11363 MB memory) -> physical GPU (device: 2, name: TITAN Xp, pci bus id: 0000:09:00.0, compute capability: 6.1)
# INFO:niftynet: Initialising Dataset from 2 subjects...
# 2019-06-18 19:19:52.185096: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1490] Adding visible gpu devices: 0, 1, 2
# 2019-06-18 19:19:52.185246: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-06-18 19:19:52.185258: I tensorflow/core/common_runtime/gpu/gpu_device.cc:977]      0 1 2
# 2019-06-18 19:19:52.185264: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 0:   N Y Y
# 2019-06-18 19:19:52.185271: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 1:   Y N Y
# 2019-06-18 19:19:52.185277: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990] 2:   Y Y N
# 2019-06-18 19:19:52.185609: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 11361 MB memory) -> physical GPU (device: 0, name: TITAN Xp, pci bus id: 0000:05:00.0, compute capability: 6.1)
# 2019-06-18 19:19:52.185855: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 11363 MB memory) -> physical GPU (device: 1, name: TITAN Xp, pci bus id: 0000:06:00.0, compute capability: 6.1)
# 2019-06-18 19:19:52.186049: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1103] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:2 with 11363 MB memory) -> physical GPU (device: 2, name: TITAN Xp, pci bus id: 0000:09:00.0, compute capability: 6.1)
# INFO:niftynet: Restoring parameters from /home/bsc0001/niftynet/models/dense_vnet_TC_craneal/models/model.ckpt-30
# Saved /home/bsc0001/niftynet/models/dense_vnet_TC_craneal/segmentation_output/000__niftynet_out.nii.gz
# Saved /home/bsc0001/niftynet/models/dense_vnet_TC_craneal/segmentation_output/000b__niftynet_out.nii.gz
# INFO:niftynet: inference iter 0,  (5.212098s)
# INFO:niftynet: cleaning up...
# INFO:niftynet: stopping sampling threads
# INFO:niftynet: SegmentationApplication stopped (time in second 6.83).

# %%
! ls /home/bsc0001/niftynet/models/dense_vnet_TC_craneal/segmentation_output
# Out:
# 000b__niftynet_out.nii.gz  000__niftynet_out.nii.gz  inferred.csv
